# %%
import os
import re
import csv
import numpy as np

# %%
cwd = os.getcwd()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # preapre CSV

# %%
# benchmark_path = "/Users/u7826985/Projects/Nvidia/results/composite_hadamard_optimization"
AA_folder ="100taxa_diff_trees_1M_sites_AA"
DNA_folder ="100taxa_diff_trees_1M_sites"

# %%
results_path = "/Users/u7826985/Projects/Nvidia/results/2026_03_03_iqtreeOpenACCGPU"
output_csv = f"{results_path}/results.csv"
output_csv_aa = f"{results_path}/results_aa.csv"

# %%
# Regex to capture the RESULT line
pattern = re.compile(
    r"\[RESULT\]\s*backend=(\w+)\s+taxa=(\d+)\s+sites=(\d+)\s+patterns=(\d+)\s+time=([\d\.e\+\-]+)s\s+likelihood=([\-.\deE]+)"
)

# %%
#read files in results_path

def read_files_in_las_reults_directory(directory, unique_name=""):
    for i in range(1, 11):
        tree_folder = f"{directory}/tree_{i}"
        files = os.listdir(tree_folder)
        op_type=""
        for file in files:
            if file.startswith("output_v100_cudaCublas_run"):
                op_type="CUDA_OLD"
            elif (file.startswith("output_v100_openACC_run") or file.startswith("output_v100_OpenACC_run")):
                op_type="OpenACC"
            else:
                continue
            if file.endswith('.txt'):
                print(f"Reading file: {file}")
                with open(f'{tree_folder}/{file}', 'r') as f:
                    #get treefile name from the txt file name
                    tree_file_name = file.split("_")[4] + "_" + file.split("_")[5]
                    # detect file name contains "a100"
                    run_number = file.split("_")[3]
                    print(tree_file_name)
                    
                    
                    
                    h200 = False
                    a100 = False
                    transposed = False
                    if "h200" in file.split("_")[-1]:
                        h200 = True
                    
                    elif "a100" in file.split("_")[-1]:
                        a100 = True
                        continue
                        
                    for line in f:
                        match = pattern.search(line)
                        if match:
                            print("found a match")
                            backend, taxa, sites, patterns, time, likelihood = match.groups()
                            backend = op_type
                            print(backend)
                            if h200:
                                backend += "_H200"
                            elif a100:
                                backend += "_A100"
                            else:
                                backend += "_V100"
                           
                                
                            # if taxa != "100":
                            #     continue
                            # backend = op_type
                            data.append([backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number])
                            
                            print(backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number)
    
                            # Write to CSV
                            # with open(output_csv, 'w', newline='') as csvfile:
                            #     writer = csv.writer(csvfile)
                            #     writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time"])
                            #     writer.writerows(data)

    print(f"Extracted {len(data)} results to {output_csv}")

# %%
#read files in results_path

def read_files_in_directory(directory, unique_name=""):
    for i in range(1, 11):
        tree_folder = f"{directory}/tree_{i}"
        files = os.listdir(tree_folder)

        for file in files:
            
            if file.endswith('.txt'):
                print(f"Reading file: {file}")
                with open(f'{tree_folder}/{file}', 'r') as f:
                    #get treefile name from the txt file name
                    tree_file_name = file.split("_")[4] + "_" + file.split("_")[5]
                    # detect file name contains "a100"
                    run_number = file.split("_")[3]
                    print(tree_file_name)
                    
                    
                    
                    h200 = False
                    a100 = False
                    transposed = False
                    if "h200" in file.split("_")[-1]:
                        h200 = True
                    
                    elif "a100" in file.split("_")[-1]:
                        a100 = True
                        continue
                        
                    for line in f:
                        match = pattern.search(line)
                        if match:
                            print("found a match")
                            backend, taxa, sites, patterns, time, likelihood = match.groups()
                            backend = "OpenACC"
                            print(backend)
                            if h200:
                                backend += "_H200"
                            elif a100:
                                backend += "_A100"
                            else:
                                backend += "_V100"
                           
                                
                            # if taxa != "100":
                            #     continue
                            # backend = op_type
                            data.append([backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number])
                            
                            print(backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number)
    
                            # Write to CSV
                            # with open(output_csv, 'w', newline='') as csvfile:
                            #     writer = csv.writer(csvfile)
                            #     writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time"])
                            #     writer.writerows(data)

    print(f"Extracted {len(data)} results to {output_csv}")

# %%
alignment_pattern = re.compile(r"Alignment has (\d+) sequences with (\d+) columns, (\d+) distinct patterns")
likelihood_pattern = re.compile(r"Initial log-likelihood:\s+([-0-9.]+)")
wallclock_pattern = re.compile(r"Total wall-clock time used:\s+([0-9.]+)\s+sec")

# %%
# Write to CSV

def write_to_csv(data, output_csv):
    with open(output_csv, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time","treefile", "run_number"])
        writer.writerows(data)

# %%
def plot_average_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    mean_times = groups['time'].mean().unstack()
    mean_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Average Time (s)')
    plt.title('Average Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()


def plot_boxplot_time_per_backend(df, logy=False, path=""):
    plt.figure(figsize=(10, 5))
    df.boxplot(column='time', by='backend')
    if logy:
        plt.yscale('log')
    plt.xlabel('Backend')
    plt.ylabel('Time (s)')
    plt.title('Time Distribution per Backend')
    plt.suptitle('')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()
    
def boxplot_per_tree_group_backend(df):
    # plot per tree file boxplot grouped by backend
    tree_files = df['treefile'].unique()
    for tree_file in tree_files:
        plt.figure(figsize=(10, 5))
        df_tree = df[df['treefile'] == tree_file]
        df_tree.boxplot(column='time', by='backend')
        plt.xlabel('Backend')
        plt.ylabel('Time (s)')
        plt.title(f'Time Distribution per Backend for {tree_file}')
        plt.suptitle('')
        plt.tight_layout()
        plt.show()

# %%
def plot_average_time_per_backend_v100(df, logy=False, path=""):
    # get only v100 backends
    df = df[df['backend'].str.contains('V100')]
    groups = df.groupby(['treefile', 'backend'])
    mean_times = groups['time'].mean().unstack()
    mean_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Average Time (s)')
    plt.title('Average Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
def plot_runtime_boxplot_auto(
    df,
    tree_col=None,
    backend_col=None,
    time_col=None,
    backend_cols=None,          # for wide format: list of backend columns
    figsize=(14, 6),
    show_outliers=True,
    title="Runtime Distribution per Tree per Backend",
    rotate_xticks=45,
    path=""
):
    """
    Auto boxplot for runtime vs tree grouped by backend.
    Works with:
      - LONG format: [tree, backend, time]
      - WIDE format: [tree, CUDA_V100, OpenACC_V100, ...] (multiple runs/rows per tree)
    """

    df = df.copy()

    # ---- 1) Detect columns if not provided ----
    cols = list(df.columns)

    # Guess tree column
    if tree_col is None:
        for c in cols:
            lc = c.lower()
            if lc in ("tree", "tree_file", "treefile", "tree_id", "treeid", "file"):
                tree_col = c
                break
        if tree_col is None:
            # fallback: first non-numeric column
            non_numeric = [c for c in cols if not pd.api.types.is_numeric_dtype(df[c])]
            tree_col = non_numeric[0] if non_numeric else cols[0]

    # If user explicitly gave wide backend columns, treat as wide
    if backend_cols is not None:
        wide_backend_cols = backend_cols
    else:
        wide_backend_cols = None

    # Determine if long format is available
    has_long = (
        (backend_col is not None and backend_col in df.columns) or
        any(c.lower() in ("backend", "impl", "implementation") for c in cols)
    ) and (
        (time_col is not None and time_col in df.columns) or
        any(c.lower() in ("time", "runtime", "elapsed", "elapsed_time", "seconds", "sec", "min_time") for c in cols)
    )

    # ---- 2) If long-format, use it ----
    if has_long:
        if backend_col is None:
            backend_col = next(c for c in cols if c.lower() in ("backend", "impl", "implementation"))
        if time_col is None:
            time_col = next(c for c in cols if c.lower() in ("time", "runtime", "elapsed", "elapsed_time", "seconds", "sec", "min_time"))

        plot_df = df[[tree_col, backend_col, time_col]].copy()
        plot_df[time_col] = pd.to_numeric(plot_df[time_col], errors="coerce")
        plot_df = plot_df.dropna(subset=[time_col])

        x, y, h = tree_col, time_col, backend_col

    # ---- 3) Otherwise assume wide-format and melt ----
    else:
        if wide_backend_cols is None:
            # pick numeric columns excluding the tree column as backend columns
            wide_backend_cols = [c for c in cols if c != tree_col]
            # keep only columns that look numeric-ish after coercion
            keep = []
            for c in wide_backend_cols:
                s = pd.to_numeric(df[c], errors="coerce")
                if s.notna().any():
                    keep.append(c)
            wide_backend_cols = keep

        if not wide_backend_cols:
            raise ValueError(
                f"Couldn't infer backend/time columns.\n"
                f"Columns seen: {cols}\n"
                f"Try providing: backend_cols=[...], and tree_col='...'"
            )

        plot_df = df[[tree_col] + wide_backend_cols].copy()
        plot_df = plot_df.melt(id_vars=[tree_col], value_vars=wide_backend_cols,
                               var_name="backend", value_name="time")
        plot_df["time"] = pd.to_numeric(plot_df["time"], errors="coerce")
        plot_df = plot_df.dropna(subset=["time"])

        x, y, h = tree_col, "time", "backend"

    # ---- 4) Plot ----
    plt.figure(figsize=figsize)
    sns.boxplot(data=plot_df, x=x, y=y, hue=h, showfliers=show_outliers)

    plt.title(title)
    plt.xlabel("Tree File")
    plt.ylabel("Time (s)")
    plt.xticks(rotation=rotate_xticks)
    plt.legend(title="Backend")
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

    # helpful debug info
    print("Using columns ->", {"tree": x, "backend": h, "time": y})
    print("Rows plotted:", len(plot_df))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_bar_with_box(df,
                      tree_col="treefile",
                      time_col="time",
                      backend_col="backend",
                      figsize=(14,6), path=""):
    """
    Plots boxplot (distribution) with mean bar overlay.
    """

    plt.figure(figsize=figsize)

    # --- Boxplot (distribution) ---
    sns.boxplot(
        data=df,
        x=tree_col,
        y=time_col,
        hue=backend_col,
        showfliers=False,
        linewidth=1
    )

    # --- Barplot (mean overlay) ---
    sns.barplot(
        data=df,
        x=tree_col,
        y=time_col,
        hue=backend_col,
        estimator="mean",
        errorbar=None,
        alpha=0.4,
        dodge=True
    )

    plt.title("Runtime Distribution + Mean per Tree per Backend")
    plt.xticks(rotation=45)
    plt.ylabel("Time (s)")
    plt.xlabel("Tree File")

    # Fix duplicate legends (because both plots create one)
    handles, labels = plt.gca().get_legend_handles_labels()
    n = len(df[backend_col].unique())
    plt.legend(handles[:n], labels[:n], title="Backend")

    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
def read_iqtree_results(directory, type="DNA"):
    for i in range(1, 11):
        tree_folder = f"{directory}/tree_{i}"
        files = os.listdir(tree_folder)
        for file in files:
            if file.endswith('.log'):
                print(f"Reading IQ-TREE file: {file}")
                with open(f'{tree_folder}/{file}', 'r') as f:
                    content = f.read()
                    # filename: output_test_iqtree_OPENACC_run1_tree_1_1000000_iqtree.log
                    #           output_test_iqtree_VANILA_run1_tree_1_1000000_aa_iqtree.log
                    parts = file.split("_")
                    extype = parts[3]           # OPENACC or VANILA
                    run_number = parts[4]        # run1, run2, ...
                    tree_file = parts[5] + "_" + parts[6]  # tree_1, tree_2, ...

                    # Extract alignment info
                    aln_match = alignment_pattern.search(content)
                    ll_match = likelihood_pattern.search(content)
                    wc_match = wallclock_pattern.search(content)

                    if aln_match and ll_match and wc_match:
                        taxa = int(aln_match.group(1))
                        sites = int(aln_match.group(2))
                        patterns = int(aln_match.group(3))
                        likelihood = float(ll_match.group(1))
                        time = float(wc_match.group(1))

                        backend = f"IQ-TREE_{extype}"

                        data.append([backend, taxa, sites, patterns, likelihood, time, tree_file, run_number])

    print(f"Extracted {len(data)} IQ-TREE results")

# %% [markdown]
# # Analysis of Results

# %%
data = []

# %%
# read_files_in_directory(f"{benchmark_path}/{AA_folder}", unique_name="_BENCHMARK")
read_files_in_directory(f"{results_path}/{AA_folder}", unique_name="_GPU")
read_iqtree_results(f"{results_path}/{AA_folder}")

write_to_csv(data, output_csv)
# Out:
# Reading file: output_poc_openACC_run9_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.458981505000000 tree_1 run9
# Reading file: output_poc_openACC_run2_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.379372021000000 tree_1 run2
# Reading file: output_poc_openACC_run10_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.279300117000000 tree_1 run10
# Reading file: output_poc_openACC_run4_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.437141026000000 tree_1 run4
# Reading file: output_poc_openACC_run8_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.468571852000000 tree_1 run8
# Reading file: output_poc_openACC_run3_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.368589791000000 tree_1 run3
# Reading file: output_poc_openACC_run5_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.582086897000000 tree_1 run5
# Reading file: output_poc_openACC_run6_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.462038147000000 tree_1 run6
# Reading file: output_poc_openACC_run1_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.315675316000000 tree_1 run1
# Reading file: output_poc_openACC_run7_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.461341883000000 tree_1 run7
# Reading file: output_poc_openACC_run7_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.522491906000000 tree_2 run7
# Reading file: output_poc_openACC_run1_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.367155609000000 tree_2 run1
# Reading file: output_poc_openACC_run6_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.540218201000000 tree_2 run6
# Reading file: output_poc_openACC_run5_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.547563323000000 tree_2 run5
# Reading file: output_poc_openACC_run8_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.443104585000000 tree_2 run8
# Reading file: output_poc_openACC_run3_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.445495677000000 tree_2 run3
# Reading file: output_poc_openACC_run4_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.409351601000000 tree_2 run4
# Reading file: output_poc_openACC_run10_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.261309449000000 tree_2 run10
# Reading file: output_poc_openACC_run9_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.436267279000000 tree_2 run9
# Reading file: output_poc_openACC_run2_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.440517399000000 tree_2 run2
# Reading file: output_poc_openACC_run6_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.477139041000000 tree_3 run6
# Reading file: output_poc_openACC_run7_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.492960791000000 tree_3 run7
# Reading file: output_poc_openACC_run1_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.299308780000000 tree_3 run1
# Reading file: output_poc_openACC_run10_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.255754455000000 tree_3 run10
# Reading file: output_poc_openACC_run4_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.407678458000000 tree_3 run4
# Reading file: output_poc_openACC_run9_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.411689880000000 tree_3 run9
# Reading file: output_poc_openACC_run2_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.393505513000000 tree_3 run2
# Reading file: output_poc_openACC_run5_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.559030915000000 tree_3 run5
# Reading file: output_poc_openACC_run8_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.428146355000000 tree_3 run8
# Reading file: output_poc_openACC_run3_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.424239014000000 tree_3 run3
# Reading file: output_poc_openACC_run2_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.428518669000000 tree_4 run2
# Reading file: output_poc_openACC_run9_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.414597266000000 tree_4 run9
# Reading file: output_poc_openACC_run4_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.453465354000000 tree_4 run4
# Reading file: output_poc_openACC_run10_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.266969586000000 tree_4 run10
# Reading file: output_poc_openACC_run3_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.397660336000000 tree_4 run3
# Reading file: output_poc_openACC_run8_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.442556188000000 tree_4 run8
# Reading file: output_poc_openACC_run5_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.582321999000000 tree_4 run5
# Reading file: output_poc_openACC_run6_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.364977317000000 tree_4 run6
# Reading file: output_poc_openACC_run1_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.293612470000000 tree_4 run1
# Reading file: output_poc_openACC_run7_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.400749562000000 tree_4 run7
# Reading file: output_poc_openACC_run3_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.435577233000000 tree_5 run3
# Reading file: output_poc_openACC_run8_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.431691297000000 tree_5 run8
# Reading file: output_poc_openACC_run5_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.534526171000000 tree_5 run5
# Reading file: output_poc_openACC_run2_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.371392184000000 tree_5 run2
# Reading file: output_poc_openACC_run9_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.430254170000000 tree_5 run9
# Reading file: output_poc_openACC_run10_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.223056545000000 tree_5 run10
# Reading file: output_poc_openACC_run4_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.442015540000000 tree_5 run4
# Reading file: output_poc_openACC_run1_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.265928289000000 tree_5 run1
# Reading file: output_poc_openACC_run7_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.390143187000000 tree_5 run7
# Reading file: output_poc_openACC_run6_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.349907004000000 tree_5 run6
# Reading file: output_poc_openACC_run6_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.422394985000000 tree_6 run6
# Reading file: output_poc_openACC_run7_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.432182404000000 tree_6 run7
# Reading file: output_poc_openACC_run1_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.275422509000000 tree_6 run1
# Reading file: output_poc_openACC_run4_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.442434201000000 tree_6 run4
# Reading file: output_poc_openACC_run10_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.250780378000000 tree_6 run10
# Reading file: output_poc_openACC_run2_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.439419265000000 tree_6 run2
# Reading file: output_poc_openACC_run9_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.522585197000000 tree_6 run9
# Reading file: output_poc_openACC_run5_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.560031767000000 tree_6 run5
# Reading file: output_poc_openACC_run3_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.395686516000000 tree_6 run3
# Reading file: output_poc_openACC_run8_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.445474995000000 tree_6 run8
# Reading file: output_poc_openACC_run7_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.367118952000000 tree_7 run7
# Reading file: output_poc_openACC_run1_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.285919244000000 tree_7 run1
# Reading file: output_poc_openACC_run6_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.399370912000000 tree_7 run6
# Reading file: output_poc_openACC_run5_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.515083153000000 tree_7 run5
# Reading file: output_poc_openACC_run3_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.384475589000000 tree_7 run3
# Reading file: output_poc_openACC_run8_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.411332747000000 tree_7 run8
# Reading file: output_poc_openACC_run10_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.246959815000000 tree_7 run10
# Reading file: output_poc_openACC_run4_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.446604047000000 tree_7 run4
# Reading file: output_poc_openACC_run2_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.336484987000000 tree_7 run2
# Reading file: output_poc_openACC_run9_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.425241555000000 tree_7 run9
# Reading file: output_poc_openACC_run1_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.280383446000000 tree_8 run1
# Reading file: output_poc_openACC_run7_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.406303761000000 tree_8 run7
# Reading file: output_poc_openACC_run6_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.417577494000000 tree_8 run6
# Reading file: output_poc_openACC_run3_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.534820007000000 tree_8 run3
# Reading file: output_poc_openACC_run8_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.430682749000000 tree_8 run8
# Reading file: output_poc_openACC_run5_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.440138726000000 tree_8 run5
# Reading file: output_poc_openACC_run2_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.429656119000000 tree_8 run2
# Reading file: output_poc_openACC_run9_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.409152434000000 tree_8 run9
# Reading file: output_poc_openACC_run4_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.589139953000000 tree_8 run4
# Reading file: output_poc_openACC_run10_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.428975944000000 tree_8 run10
# Reading file: output_poc_openACC_run6_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.425842131000000 tree_9 run6
# Reading file: output_poc_openACC_run1_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.270721911000000 tree_9 run1
# Reading file: output_poc_openACC_run7_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.512599957000000 tree_9 run7
# Reading file: output_poc_openACC_run2_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.357980868000000 tree_9 run2
# Reading file: output_poc_openACC_run9_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.445189062000000 tree_9 run9
# Reading file: output_poc_openACC_run10_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.332451706000000 tree_9 run10
# Reading file: output_poc_openACC_run4_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.412792472000000 tree_9 run4
# Reading file: output_poc_openACC_run3_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.380544641000000 tree_9 run3
# Reading file: output_poc_openACC_run8_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.459253182000000 tree_9 run8
# Reading file: output_poc_openACC_run5_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.451761560000000 tree_9 run5
# Reading file: output_poc_openACC_run4_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.424603272000000 tree_10 run4
# Reading file: output_poc_openACC_run8_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.437353911000000 tree_10 run8
# Reading file: output_poc_openACC_run7_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.416270890000000 tree_10 run7
# Reading file: output_poc_openACC_run10_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.254622328000000 tree_10 run10
# Reading file: output_poc_openACC_run2_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.355541316000000 tree_10 run2
# Reading file: output_poc_openACC_run1_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.263838361000000 tree_10 run1
# Reading file: output_poc_openACC_run5_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.354433402000000 tree_10 run5
# Reading file: output_poc_openACC_run9_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.400628273000000 tree_10 run9
# Reading file: output_poc_openACC_run6_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.435485548000000 tree_10 run6
# Reading file: output_poc_openACC_run3_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.370932769000000 tree_10 run3
# Extracted 100 results to /Users/u7826985/Projects/Nvidia/results/2026_03_03_iqtreeOpenACCGPU/results.csv
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_1_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_2_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_3_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_4_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_5_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_6_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_7_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_8_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_9_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_10_1000000_aa_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_10_1000000_aa_iqtree.log
# Extracted 300 IQ-TREE results

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(output_csv)
# Display the first few rows of the DataFrame
df
# Out:
#              backend  taxa    sites  patterns    likelihood       time  \
# 0       OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.458982
# 1       OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.379372
# 2       OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.279300
# 3       OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.437141
# 4       OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.468572
# ..               ...   ...      ...       ...           ...        ...
# 295  IQ-TREE_OPENACC   100  1000000   1000000 -1.065590e+08  26.110000
# 296  IQ-TREE_OPENACC   100  1000000   1000000 -1.065590e+08  25.181000
# 297  IQ-TREE_OPENACC   100  1000000   1000000 -1.065590e+08  29.046000
# 298   IQ-TREE_VANILA   100  1000000   1000000 -1.065590e+08  15.828000
# 299   IQ-TREE_VANILA   100  1000000   1000000 -1.065590e+08  15.908000
#
#     treefile run_number
# 0     tree_1       run9
# 1     tree_1       run2
# 2     tree_1      run10
# 3     tree_1       run4
# 4     tree_1       run8
# ..       ...        ...
# 295  tree_10       run3
# 296  tree_10       run5
# 297  tree_10       run2
# 298  tree_10       run8
# 299  tree_10       run7
#
# [300 rows x 8 columns]

# %%
plot_runtime_boxplot_auto(df, path=f"{cwd}/aa_boxonly.png")
# Out:
# Using columns -> {'tree': 'treefile', 'backend': 'backend', 'time': 'time'}
# Rows plotted: 300

# %%
plot_bar_with_box(df, path=f"{cwd}/aa_boxplot.png")

# %%
def plot_min_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    min_times = groups['time'].min().unstack()
    min_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Min Time (s)')
    plt.title('Minimum Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
plot_min_time_per_backend(df, logy=False, path=f"{cwd}/min_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
plot_average_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
def plot_max_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    max_times = groups['time'].max().unstack()
    max_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Max Time (s)')
    plt.title('Max Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
plot_max_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
plot_average_time_per_backend_v100(df, logy=False, path=f"{cwd}/average_time_per_backend_v100_100taxa_diff_trees_1M_sites_AA.png")

# %%
# boxplot_per_tree_group_backend(df)
# plot_boxplot_time_per_backend(df, logy=False, path=f"{cwd}/boxplot_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
data = []
read_files_in_directory(f"{results_path}/{DNA_folder}", unique_name="_GPU")
read_iqtree_results(f"{results_path}/{DNA_folder}")
write_to_csv(data, output_csv_aa)
df = pd.read_csv(output_csv_aa)
# Out:
# Reading file: output_poc_openACC_run9_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.261742229000000 tree_1 run9
# Reading file: output_poc_openACC_run6_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.393108619000000 tree_1 run6
# Reading file: output_poc_openACC_run5_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.278225986000000 tree_1 run5
# Reading file: output_poc_openACC_run3_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.166528501000000 tree_1 run3
# Reading file: output_poc_openACC_run8_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.301029318000000 tree_1 run8
# Reading file: output_poc_openACC_run7_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.301964195000000 tree_1 run7
# Reading file: output_poc_openACC_run4_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.289593234000000 tree_1 run4
# Reading file: output_poc_openACC_run1_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.198506341000000 tree_1 run1
# Reading file: output_poc_openACC_run10_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.268143008000000 tree_1 run10
# Reading file: output_poc_openACC_run2_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.168228596000000 tree_1 run2
# Reading file: output_poc_openACC_run5_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.272556979000000 tree_2 run5
# Reading file: output_poc_openACC_run6_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.255584236000000 tree_2 run6
# Reading file: output_poc_openACC_run9_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.229275318000000 tree_2 run9
# Reading file: output_poc_openACC_run3_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.172311261000000 tree_2 run3
# Reading file: output_poc_openACC_run4_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.248594194000000 tree_2 run4
# Reading file: output_poc_openACC_run7_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.249636403000000 tree_2 run7
# Reading file: output_poc_openACC_run8_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.230978210000000 tree_2 run8
# Reading file: output_poc_openACC_run2_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.111178951000000 tree_2 run2
# Reading file: output_poc_openACC_run10_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.204563165000000 tree_2 run10
# Reading file: output_poc_openACC_run1_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.170895181000000 tree_2 run1
# Reading file: output_poc_openACC_run1_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.243095031000000 tree_3 run1
# Reading file: output_poc_openACC_run2_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.114430365000000 tree_3 run2
# Reading file: output_poc_openACC_run10_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.269092610000000 tree_3 run10
# Reading file: output_poc_openACC_run7_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.255833913000000 tree_3 run7
# Reading file: output_poc_openACC_run8_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.268443924000000 tree_3 run8
# Reading file: output_poc_openACC_run4_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.238179366000000 tree_3 run4
# Reading file: output_poc_openACC_run3_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.141624775000000 tree_3 run3
# Reading file: output_poc_openACC_run6_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.257572908000000 tree_3 run6
# Reading file: output_poc_openACC_run9_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.266012563000000 tree_3 run9
# Reading file: output_poc_openACC_run5_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.275626894000000 tree_3 run5
# Reading file: output_poc_openACC_run3_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.192182466000000 tree_4 run3
# Reading file: output_poc_openACC_run6_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.269096986000000 tree_4 run6
# Reading file: output_poc_openACC_run9_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.216158183000000 tree_4 run9
# Reading file: output_poc_openACC_run5_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.271748462000000 tree_4 run5
# Reading file: output_poc_openACC_run1_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.167759090000000 tree_4 run1
# Reading file: output_poc_openACC_run2_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.220867164000000 tree_4 run2
# Reading file: output_poc_openACC_run10_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.325630865000000 tree_4 run10
# Reading file: output_poc_openACC_run7_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.254545283000000 tree_4 run7
# Reading file: output_poc_openACC_run8_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.235909062000000 tree_4 run8
# Reading file: output_poc_openACC_run4_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.242152816000000 tree_4 run4
# Reading file: output_poc_openACC_run4_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.256884774000000 tree_5 run4
# Reading file: output_poc_openACC_run7_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.249204621000000 tree_5 run7
# Reading file: output_poc_openACC_run8_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.246770151000000 tree_5 run8
# Reading file: output_poc_openACC_run2_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.114436912000000 tree_5 run2
# Reading file: output_poc_openACC_run10_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.256151596000000 tree_5 run10
# Reading file: output_poc_openACC_run1_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.161248730000000 tree_5 run1
# Reading file: output_poc_openACC_run5_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.255353692000000 tree_5 run5
# Reading file: output_poc_openACC_run6_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.255862524000000 tree_5 run6
# Reading file: output_poc_openACC_run9_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.236697507000000 tree_5 run9
# Reading file: output_poc_openACC_run3_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.177427022000000 tree_5 run3
# Reading file: output_poc_openACC_run8_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.241924515000000 tree_6 run8
# Reading file: output_poc_openACC_run7_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.299002608000000 tree_6 run7
# Reading file: output_poc_openACC_run4_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.217878610000000 tree_6 run4
# Reading file: output_poc_openACC_run1_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.167599162000000 tree_6 run1
# Reading file: output_poc_openACC_run10_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.238541406000000 tree_6 run10
# Reading file: output_poc_openACC_run2_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.133230226000000 tree_6 run2
# Reading file: output_poc_openACC_run9_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.203832938000000 tree_6 run9
# Reading file: output_poc_openACC_run6_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.360720986000000 tree_6 run6
# Reading file: output_poc_openACC_run5_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.301387938000000 tree_6 run5
# Reading file: output_poc_openACC_run3_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.164133037000000 tree_6 run3
# Reading file: output_poc_openACC_run3_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.175795783000000 tree_7 run3
# Reading file: output_poc_openACC_run5_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.269188567000000 tree_7 run5
# Reading file: output_poc_openACC_run9_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.205459687000000 tree_7 run9
# Reading file: output_poc_openACC_run6_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.247694763000000 tree_7 run6
# Reading file: output_poc_openACC_run10_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.203992401000000 tree_7 run10
# Reading file: output_poc_openACC_run2_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.124364122000000 tree_7 run2
# Reading file: output_poc_openACC_run1_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.150206817000000 tree_7 run1
# Reading file: output_poc_openACC_run4_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.239712830000000 tree_7 run4
# Reading file: output_poc_openACC_run8_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.252477979000000 tree_7 run8
# Reading file: output_poc_openACC_run7_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.253246923000000 tree_7 run7
# Reading file: output_poc_openACC_run8_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.251887767000000 tree_8 run8
# Reading file: output_poc_openACC_run7_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.193266144000000 tree_8 run7
# Reading file: output_poc_openACC_run4_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.203306762000000 tree_8 run4
# Reading file: output_poc_openACC_run1_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.142106373000000 tree_8 run1
# Reading file: output_poc_openACC_run10_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.225058583000000 tree_8 run10
# Reading file: output_poc_openACC_run2_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.141981918000000 tree_8 run2
# Reading file: output_poc_openACC_run9_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.250802517000000 tree_8 run9
# Reading file: output_poc_openACC_run6_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.237604760000000 tree_8 run6
# Reading file: output_poc_openACC_run5_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.280375594000000 tree_8 run5
# Reading file: output_poc_openACC_run3_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.135698052000000 tree_8 run3
# Reading file: output_poc_openACC_run3_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.170452848000000 tree_9 run3
# Reading file: output_poc_openACC_run5_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.312407953000000 tree_9 run5
# Reading file: output_poc_openACC_run9_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.247123618000000 tree_9 run9
# Reading file: output_poc_openACC_run6_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.278134465000000 tree_9 run6
# Reading file: output_poc_openACC_run10_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.217982232000000 tree_9 run10
# Reading file: output_poc_openACC_run2_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.125554950000000 tree_9 run2
# Reading file: output_poc_openACC_run1_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.152521843000000 tree_9 run1
# Reading file: output_poc_openACC_run4_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.338933826000000 tree_9 run4
# Reading file: output_poc_openACC_run8_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.235255519000000 tree_9 run8
# Reading file: output_poc_openACC_run7_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.315741744000000 tree_9 run7
# Reading file: output_poc_openACC_run6_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.283492544000000 tree_10 run6
# Reading file: output_poc_openACC_run1_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.154653054000000 tree_10 run1
# Reading file: output_poc_openACC_run7_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.324660875000000 tree_10 run7
# Reading file: output_poc_openACC_run9_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.500917754000000 tree_10 run9
# Reading file: output_poc_openACC_run10_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.252597417000000 tree_10 run10
# Reading file: output_poc_openACC_run8_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.480586652000000 tree_10 run8
# Reading file: output_poc_openACC_run2_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.124807264000000 tree_10 run2
# Reading file: output_poc_openACC_run5_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.317678985000000 tree_10 run5
# Reading file: output_poc_openACC_run3_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.160878873000000 tree_10 run3
# Reading file: output_poc_openACC_run4_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.300690820000000 tree_10 run4
# Extracted 100 results to /Users/u7826985/Projects/Nvidia/results/2026_03_03_iqtreeOpenACCGPU/results.csv
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_1_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_2_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_3_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_4_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_5_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_6_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_7_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_8_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_9_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run2_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run9_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run10_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run5_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run7_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run8_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run10_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run4_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run6_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run1_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run3_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run4_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run8_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run6_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run1_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run3_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run2_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run5_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_VANILA_run9_tree_10_1000000_iqtree.log
# Reading IQ-TREE file: output_test_iqtree_OPENACC_run7_tree_10_1000000_iqtree.log
# Extracted 300 IQ-TREE results

# %%
df
# Out:
#              backend  taxa    sites  patterns    likelihood      time  \
# 0       OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.261742
# 1       OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.393109
# 2       OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.278226
# 3       OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.166529
# 4       OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.301029
# ..               ...   ...      ...       ...           ...       ...
# 295   IQ-TREE_VANILA   100  1000000   1000000 -6.804077e+07  4.376000
# 296   IQ-TREE_VANILA   100  1000000   1000000 -6.804077e+07  4.352000
# 297   IQ-TREE_VANILA   100  1000000   1000000 -6.804077e+07  4.350000
# 298   IQ-TREE_VANILA   100  1000000   1000000 -6.804077e+07  4.343000
# 299  IQ-TREE_OPENACC   100  1000000   1000000 -6.804077e+07  8.951000
#
#     treefile run_number
# 0     tree_1       run9
# 1     tree_1       run6
# 2     tree_1       run5
# 3     tree_1       run3
# 4     tree_1       run8
# ..       ...        ...
# 295  tree_10       run3
# 296  tree_10       run2
# 297  tree_10       run5
# 298  tree_10       run9
# 299  tree_10       run7
#
# [300 rows x 8 columns]

# %%
plot_average_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_DNA.png")

# %%
# plot_min_time_per_backend(df, logy=False, path=f"{cwd}/min_time_per_backend_100taxa_diff_trees_1M_sites_DNA.png")

# %%
plot_average_time_per_backend_v100(df, logy=False, path=f"{cwd}/average_time_per_backend_v100_100taxa_diff_trees_1M_sites_DNA.png")

# %%
plot_runtime_boxplot_auto(df, path="DNA_boxonlyplot.png")
# Out:
# Using columns -> {'tree': 'treefile', 'backend': 'backend', 'time': 'time'}
# Rows plotted: 300

# %%
plot_bar_with_box(df, path="DNA_boxplot.png")
