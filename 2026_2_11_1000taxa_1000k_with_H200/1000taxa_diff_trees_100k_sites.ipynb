# %%
import os
import re
import csv
import numpy as np

# %%
cwd = os.getcwd()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # preapre CSV

# %%
# benchmark_path = "/Users/u7826985/Projects/Nvidia/results/composite_hadamard_optimization"
AA_folder ="1000taxa_diff_trees_100K_sites_AA"
# DNA_folder ="100taxa_diff_trees_1M_sites"

# %%
# last_results_path = "/Users/u7826985/Projects/Nvidia/results/2025_10_20_a100_vs_c100"
results_path = "/Users/u7826985/Projects/Nvidia/results/2026_02_10_h200_gpu"
output_csv = f"{results_path}/results.csv"
output_csv_aa = f"{results_path}/results_aa.csv"

# %%
# Regex to capture the RESULT line
pattern = re.compile(
    r"\[RESULT\]\s*backend=(\w+)\s+taxa=(\d+)\s+sites=(\d+)\s+patterns=(\d+)\s+time=([\d\.e\+\-]+)s\s+likelihood=([\-.\deE]+)"
)

# %%
#read files in results_path

def read_files_in_directory(directory, unique_name=""):
    for i in range(1, 11):
        tree_folder = f"{directory}/tree_{i}"
        files = os.listdir(tree_folder)
        for file in files:
            if file.endswith('.txt'):
                print(f"Reading file: {file}")
                with open(f'{tree_folder}/{file}', 'r') as f:
                    #get treefile name from the txt file name
                    tree_file_name = file.split("_")[4] + "_" + file.split("_")[5]
                    # detect file name contains "a100"
                    run_number = file.split("_")[3]
                    print(tree_file_name)
                    
                    h200 = False
                    a100 = False
                    transposed = False
                    if "h200" in file.split("_")[-1]:
                        h200 = True
                    
                    elif "a100" in file.split("_")[-1]:
                        a100 = True
                        continue
                        
                    for line in f:
                        match = pattern.search(line)
                        
                        if match:
                            print("found a match")
                            backend, taxa, sites, patterns, time, likelihood = match.groups()
                            print(backend)
                            if h200:
                                backend += "_H200"
                            elif a100:
                                backend += "_A100"
                            else:
                                backend += "_V100"
                           
                                
                            # if taxa != "100":
                            #     continue
                            backend += unique_name
                            data.append([backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number])
                            
                            print(backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number)
    
                            # Write to CSV
                            # with open(output_csv, 'w', newline='') as csvfile:
                            #     writer = csv.writer(csvfile)
                            #     writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time"])
                            #     writer.writerows(data)

    print(f"Extracted {len(data)} results to {output_csv}")

# %%
alignment_pattern = re.compile(r"Alignment has (\d+) sequences with (\d+) columns, (\d+) distinct patterns")
likelihood_pattern = re.compile(r"Initial log-likelihood:\s+([-0-9.]+).*?took ([0-9.]+) wall-clock sec")

# Data list
# data = []

# %%
# Write to CSV

def write_to_csv(data, output_csv):
    with open(output_csv, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time","treefile", "run_number"])
        writer.writerows(data)

# %%
def plot_average_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    mean_times = groups['time'].mean().unstack()
    mean_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Average Time (s)')
    plt.title('Average Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()


def plot_boxplot_time_per_backend(df, logy=False, path=""):
    plt.figure(figsize=(10, 5))
    df.boxplot(column='time', by='backend')
    if logy:
        plt.yscale('log')
    plt.xlabel('Backend')
    plt.ylabel('Time (s)')
    plt.title('Time Distribution per Backend')
    plt.suptitle('')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()
    
def boxplot_per_tree_group_backend(df):
    # plot per tree file boxplot grouped by backend
    tree_files = df['treefile'].unique()
    for tree_file in tree_files:
        plt.figure(figsize=(10, 5))
        df_tree = df[df['treefile'] == tree_file]
        df_tree.boxplot(column='time', by='backend')
        plt.xlabel('Backend')
        plt.ylabel('Time (s)')
        plt.title(f'Time Distribution per Backend for {tree_file}')
        plt.suptitle('')
        plt.tight_layout()
        plt.show()

# %%
def plot_average_time_per_backend_v100(df, logy=False, path=""):
    # get only v100 backends
    df = df[df['backend'].str.contains('V100')]
    groups = df.groupby(['treefile', 'backend'])
    mean_times = groups['time'].mean().unstack()
    mean_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Average Time (s)')
    plt.title('Average Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %% [markdown]
# # Analysis of Results

# %%
data = []

# %%
# read_files_in_directory(f"{benchmark_path}/{AA_folder}", unique_name="_BENCHMARK")
read_files_in_directory(f"{results_path}/{AA_folder}", unique_name="_GPU")
# read_files_in_directory(f"{last_results_path}/{AA_folder}", unique_name="_OLDGPU")

write_to_csv(data, output_csv)
# Out:
# Reading file: output_openACC_h200_run8_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 2.493405754000000 tree_1 run8
# Reading file: output_openACC_a100_run2_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_v100_run3_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.512149240000000 tree_1 run3
# Reading file: output_openACC_h200_run5_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 1.807790762000000 tree_1 run5
# Reading file: output_openACC_h200_run7_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 3.148198902000000 tree_1 run7
# Reading file: output_openACC_v100_run1_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.514642943000000 tree_1 run1
# Reading file: output_openACC_h200_run9_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 2.201133332000000 tree_1 run9
# Reading file: output_openACC_v100_run10_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 2.036187395000000 tree_1 run10
# Reading file: output_openACC_v100_run2_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.535439446000000 tree_1 run2
# Reading file: output_openACC_a100_run3_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_h200_run4_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 1.425830700000000 tree_1 run4
# Reading file: output_openACC_h200_run6_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 2.417215019000000 tree_1 run6
# Reading file: output_openACC_a100_run1_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_a100_run7_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_v100_run6_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.569482548000000 tree_1 run6
# Reading file: output_openACC_h200_run10_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 3.301746459000000 tree_1 run10
# Reading file: output_openACC_a100_run8_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_v100_run9_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.853227274000000 tree_1 run9
# Reading file: output_openACC_h200_run2_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 1.226788796000000 tree_1 run2
# Reading file: output_openACC_v100_run4_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.582141920000000 tree_1 run4
# Reading file: output_openACC_a100_run5_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_v100_run7_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.713817363000000 tree_1 run7
# Reading file: output_openACC_a100_run6_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_h200_run1_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 1.113288224000000 tree_1 run1
# Reading file: output_openACC_v100_run8_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.807480153000000 tree_1 run8
# Reading file: output_openACC_a100_run9_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_a100_run10_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_h200_run3_tree_1_100000_aa_openacc_h200.txt
# tree_1
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105549278.231747955083847 1.560783176000000 tree_1 run3
# Reading file: output_openACC_a100_run4_tree_1_100000_aa_openacc_a100.txt
# tree_1
# Reading file: output_openACC_v100_run5_tree_1_100000_aa_openacc_v100.txt
# tree_1
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105549278.231747955083847 1.676319422000000 tree_1 run5
# Reading file: output_openACC_h200_run2_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 1.059556517000000 tree_2 run2
# Reading file: output_openACC_v100_run9_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.840784624000000 tree_2 run9
# Reading file: output_openACC_a100_run8_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_a100_run5_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_v100_run4_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.520846971000000 tree_2 run4
# Reading file: output_openACC_h200_run10_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 3.472977833000000 tree_2 run10
# Reading file: output_openACC_v100_run6_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.587013520000000 tree_2 run6
# Reading file: output_openACC_a100_run7_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_h200_run3_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 1.460684980000000 tree_2 run3
# Reading file: output_openACC_a100_run9_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_v100_run8_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.743467903000000 tree_2 run8
# Reading file: output_openACC_a100_run10_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_v100_run5_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.646032182000000 tree_2 run5
# Reading file: output_openACC_a100_run4_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_a100_run6_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_v100_run7_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.661196948000000 tree_2 run7
# Reading file: output_openACC_h200_run1_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 1.387426792000000 tree_2 run1
# Reading file: output_openACC_h200_run7_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 3.156098948000000 tree_2 run7
# Reading file: output_openACC_v100_run1_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.480739548000000 tree_2 run1
# Reading file: output_openACC_v100_run3_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.491467270000000 tree_2 run3
# Reading file: output_openACC_a100_run2_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_h200_run8_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 3.361817447000000 tree_2 run8
# Reading file: output_openACC_h200_run5_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 2.440222013000000 tree_2 run5
# Reading file: output_openACC_h200_run6_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 2.757580565000000 tree_2 run6
# Reading file: output_openACC_a100_run1_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_v100_run10_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.953040549000000 tree_2 run10
# Reading file: output_openACC_a100_run3_tree_2_100000_aa_openacc_a100.txt
# tree_2
# Reading file: output_openACC_v100_run2_tree_2_100000_aa_openacc_v100.txt
# tree_2
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -104255573.338635638356209 1.507271347000000 tree_2 run2
# Reading file: output_openACC_h200_run9_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 3.338107471000000 tree_2 run9
# Reading file: output_openACC_h200_run4_tree_2_100000_aa_openacc_h200.txt
# tree_2
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -104255573.338635638356209 1.400149574000000 tree_2 run4
# Reading file: output_openACC_v100_run7_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.675630384000000 tree_3 run7
# Reading file: output_openACC_a100_run6_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_h200_run1_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 1.501335053000000 tree_3 run1
# Reading file: output_openACC_h200_run3_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 1.618164746000000 tree_3 run3
# Reading file: output_openACC_v100_run8_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.734215013000000 tree_3 run8
# Reading file: output_openACC_a100_run9_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_a100_run10_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_a100_run4_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_v100_run5_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.665555541000000 tree_3 run5
# Reading file: output_openACC_h200_run10_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 3.101803985000000 tree_3 run10
# Reading file: output_openACC_a100_run7_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_v100_run6_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.492923305000000 tree_3 run6
# Reading file: output_openACC_h200_run2_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 0.968693321000000 tree_3 run2
# Reading file: output_openACC_a100_run8_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_v100_run9_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.875433496000000 tree_3 run9
# Reading file: output_openACC_v100_run4_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.523040047000000 tree_3 run4
# Reading file: output_openACC_a100_run5_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_v100_run10_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 2.051841876000000 tree_3 run10
# Reading file: output_openACC_v100_run2_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.528688442000000 tree_3 run2
# Reading file: output_openACC_a100_run3_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_h200_run9_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 3.476976820000000 tree_3 run9
# Reading file: output_openACC_h200_run4_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 1.342378372000000 tree_3 run4
# Reading file: output_openACC_h200_run6_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 3.040987418000000 tree_3 run6
# Reading file: output_openACC_a100_run1_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_a100_run2_tree_3_100000_aa_openacc_a100.txt
# tree_3
# Reading file: output_openACC_v100_run3_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.571454921000000 tree_3 run3
# Reading file: output_openACC_h200_run8_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 3.167106481000000 tree_3 run8
# Reading file: output_openACC_h200_run5_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 2.867622570000000 tree_3 run5
# Reading file: output_openACC_h200_run7_tree_3_100000_aa_openacc_h200.txt
# tree_3
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102353843.075708538293839 2.852342063000000 tree_3 run7
# Reading file: output_openACC_v100_run1_tree_3_100000_aa_openacc_v100.txt
# tree_3
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102353843.075708538293839 1.471262818000000 tree_3 run1
# Reading file: output_openACC_v100_run5_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.727562488000000 tree_4 run5
# Reading file: output_openACC_a100_run4_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_a100_run10_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_a100_run9_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_v100_run8_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.835561726000000 tree_4 run8
# Reading file: output_openACC_h200_run3_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 1.417348172000000 tree_4 run3
# Reading file: output_openACC_h200_run1_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 1.017578321000000 tree_4 run1
# Reading file: output_openACC_a100_run6_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_v100_run7_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.640071012000000 tree_4 run7
# Reading file: output_openACC_a100_run5_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_v100_run4_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.552246722000000 tree_4 run4
# Reading file: output_openACC_v100_run9_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.769858589000000 tree_4 run9
# Reading file: output_openACC_a100_run8_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_h200_run2_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 1.202758829000000 tree_4 run2
# Reading file: output_openACC_v100_run6_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.491344004000000 tree_4 run6
# Reading file: output_openACC_a100_run7_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_h200_run10_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 3.007598510000000 tree_4 run10
# Reading file: output_openACC_a100_run1_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_h200_run6_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 3.163759646000000 tree_4 run6
# Reading file: output_openACC_h200_run4_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 1.641425654000000 tree_4 run4
# Reading file: output_openACC_h200_run9_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 3.276087823000000 tree_4 run9
# Reading file: output_openACC_v100_run10_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.960365438000000 tree_4 run10
# Reading file: output_openACC_a100_run3_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_v100_run2_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.535043036000000 tree_4 run2
# Reading file: output_openACC_v100_run1_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.481133795000000 tree_4 run1
# Reading file: output_openACC_h200_run7_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 2.505112978000000 tree_4 run7
# Reading file: output_openACC_h200_run5_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 2.921007647000000 tree_4 run5
# Reading file: output_openACC_h200_run8_tree_4_100000_aa_openacc_h200.txt
# tree_4
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103263873.443830534815788 2.937479639000000 tree_4 run8
# Reading file: output_openACC_v100_run3_tree_4_100000_aa_openacc_v100.txt
# tree_4
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103263873.443830534815788 1.481638582000000 tree_4 run3
# Reading file: output_openACC_a100_run2_tree_4_100000_aa_openacc_a100.txt
# tree_4
# Reading file: output_openACC_a100_run7_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_v100_run6_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.547212991000000 tree_5 run6
# Reading file: output_openACC_h200_run10_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 3.434680897000000 tree_5 run10
# Reading file: output_openACC_v100_run4_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.522485017000000 tree_5 run4
# Reading file: output_openACC_a100_run5_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_a100_run8_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_v100_run9_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.807268015000000 tree_5 run9
# Reading file: output_openACC_h200_run2_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 1.002543622000000 tree_5 run2
# Reading file: output_openACC_h200_run1_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 1.207442724000000 tree_5 run1
# Reading file: output_openACC_v100_run7_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.649293102000000 tree_5 run7
# Reading file: output_openACC_a100_run6_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_a100_run4_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_v100_run5_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.635182502000000 tree_5 run5
# Reading file: output_openACC_a100_run10_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_v100_run8_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.738236742000000 tree_5 run8
# Reading file: output_openACC_a100_run9_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_h200_run3_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 1.917802063000000 tree_5 run3
# Reading file: output_openACC_h200_run5_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 2.579169649000000 tree_5 run5
# Reading file: output_openACC_h200_run8_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 3.962482871000000 tree_5 run8
# Reading file: output_openACC_a100_run2_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_v100_run3_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.488644998000000 tree_5 run3
# Reading file: output_openACC_v100_run1_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.561608230000000 tree_5 run1
# Reading file: output_openACC_h200_run7_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 2.145945473000000 tree_5 run7
# Reading file: output_openACC_h200_run4_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 1.789747404000000 tree_5 run4
# Reading file: output_openACC_h200_run9_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 2.832718444000000 tree_5 run9
# Reading file: output_openACC_v100_run10_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.921367089000000 tree_5 run10
# Reading file: output_openACC_v100_run2_tree_5_100000_aa_openacc_v100.txt
# tree_5
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103011878.367386072874069 1.528723643000000 tree_5 run2
# Reading file: output_openACC_a100_run3_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_a100_run1_tree_5_100000_aa_openacc_a100.txt
# tree_5
# Reading file: output_openACC_h200_run6_tree_5_100000_aa_openacc_h200.txt
# tree_5
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103011878.367386072874069 2.512311047000000 tree_5 run6
# Reading file: output_openACC_v100_run1_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.518954895000000 tree_6 run1
# Reading file: output_openACC_h200_run7_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 2.492750289000000 tree_6 run7
# Reading file: output_openACC_h200_run5_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 1.996643872000000 tree_6 run5
# Reading file: output_openACC_v100_run3_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.489364402000000 tree_6 run3
# Reading file: output_openACC_a100_run2_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_h200_run8_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 1.761914354000000 tree_6 run8
# Reading file: output_openACC_a100_run1_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_h200_run6_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 1.923851246000000 tree_6 run6
# Reading file: output_openACC_h200_run4_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 1.559198365000000 tree_6 run4
# Reading file: output_openACC_v100_run10_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.882267071000000 tree_6 run10
# Reading file: output_openACC_a100_run3_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_v100_run2_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.517952769000000 tree_6 run2
# Reading file: output_openACC_h200_run9_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 2.239482290000000 tree_6 run9
# Reading file: output_openACC_a100_run5_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_v100_run4_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.488953966000000 tree_6 run4
# Reading file: output_openACC_h200_run2_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 1.021551100000000 tree_6 run2
# Reading file: output_openACC_v100_run9_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.744929454000000 tree_6 run9
# Reading file: output_openACC_a100_run8_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_h200_run10_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 3.532941897000000 tree_6 run10
# Reading file: output_openACC_v100_run6_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.495589004000000 tree_6 run6
# Reading file: output_openACC_a100_run7_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_v100_run5_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.630966426000000 tree_6 run5
# Reading file: output_openACC_a100_run4_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_h200_run3_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 1.378583927000000 tree_6 run3
# Reading file: output_openACC_a100_run10_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_a100_run9_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_v100_run8_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.780432479000000 tree_6 run8
# Reading file: output_openACC_h200_run1_tree_6_100000_aa_openacc_h200.txt
# tree_6
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105561490.937885910272598 1.186812394000000 tree_6 run1
# Reading file: output_openACC_a100_run6_tree_6_100000_aa_openacc_a100.txt
# tree_6
# Reading file: output_openACC_v100_run7_tree_6_100000_aa_openacc_v100.txt
# tree_6
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105561490.937885910272598 1.726730681000000 tree_6 run7
# Reading file: output_openACC_h200_run4_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 1.569889633000000 tree_7 run4
# Reading file: output_openACC_v100_run10_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.872017063000000 tree_7 run10
# Reading file: output_openACC_v100_run2_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.515020718000000 tree_7 run2
# Reading file: output_openACC_a100_run3_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_h200_run9_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 2.964545985000000 tree_7 run9
# Reading file: output_openACC_a100_run1_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_h200_run6_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 3.612730319000000 tree_7 run6
# Reading file: output_openACC_h200_run5_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 3.647659191000000 tree_7 run5
# Reading file: output_openACC_a100_run2_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_v100_run3_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.480222184000000 tree_7 run3
# Reading file: output_openACC_h200_run8_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 2.958740461000000 tree_7 run8
# Reading file: output_openACC_v100_run1_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.490933914000000 tree_7 run1
# Reading file: output_openACC_h200_run7_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 2.504854422000000 tree_7 run7
# Reading file: output_openACC_h200_run1_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 1.129276627000000 tree_7 run1
# Reading file: output_openACC_v100_run7_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.698997722000000 tree_7 run7
# Reading file: output_openACC_a100_run6_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_a100_run4_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_v100_run5_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.582491743000000 tree_7 run5
# Reading file: output_openACC_h200_run3_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 1.634027138000000 tree_7 run3
# Reading file: output_openACC_a100_run10_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_v100_run8_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.736554359000000 tree_7 run8
# Reading file: output_openACC_a100_run9_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_h200_run10_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 2.071931830000000 tree_7 run10
# Reading file: output_openACC_a100_run7_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_v100_run6_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.508201811000000 tree_7 run6
# Reading file: output_openACC_v100_run4_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.581812758000000 tree_7 run4
# Reading file: output_openACC_a100_run5_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_h200_run2_tree_7_100000_aa_openacc_h200.txt
# tree_7
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -102384632.468768984079361 0.984195684000000 tree_7 run2
# Reading file: output_openACC_a100_run8_tree_7_100000_aa_openacc_a100.txt
# tree_7
# Reading file: output_openACC_v100_run9_tree_7_100000_aa_openacc_v100.txt
# tree_7
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -102384632.468768984079361 1.840831530000000 tree_7 run9
# Reading file: output_openACC_a100_run4_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_v100_run5_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.719730935000000 tree_8 run5
# Reading file: output_openACC_v100_run8_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.687065757000000 tree_8 run8
# Reading file: output_openACC_a100_run9_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_a100_run10_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_h200_run3_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 1.463575794000000 tree_8 run3
# Reading file: output_openACC_h200_run1_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 1.154998672000000 tree_8 run1
# Reading file: output_openACC_v100_run7_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.715184022000000 tree_8 run7
# Reading file: output_openACC_a100_run6_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_v100_run4_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.538924893000000 tree_8 run4
# Reading file: output_openACC_a100_run5_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_a100_run8_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_v100_run9_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.852678064000000 tree_8 run9
# Reading file: output_openACC_h200_run2_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 1.148463513000000 tree_8 run2
# Reading file: output_openACC_a100_run7_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_v100_run6_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.493071549000000 tree_8 run6
# Reading file: output_openACC_h200_run10_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 4.628938759000000 tree_8 run10
# Reading file: output_openACC_a100_run1_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_h200_run6_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 2.842644037000000 tree_8 run6
# Reading file: output_openACC_h200_run4_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 1.662656088000000 tree_8 run4
# Reading file: output_openACC_h200_run9_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 4.665063289000000 tree_8 run9
# Reading file: output_openACC_v100_run2_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.533419217000000 tree_8 run2
# Reading file: output_openACC_a100_run3_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_v100_run10_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.885471719000000 tree_8 run10
# Reading file: output_openACC_v100_run1_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.542676739000000 tree_8 run1
# Reading file: output_openACC_h200_run7_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 2.556090435000000 tree_8 run7
# Reading file: output_openACC_h200_run5_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 2.927078996000000 tree_8 run5
# Reading file: output_openACC_h200_run8_tree_8_100000_aa_openacc_h200.txt
# tree_8
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105595084.235052585601807 4.549878104000000 tree_8 run8
# Reading file: output_openACC_a100_run2_tree_8_100000_aa_openacc_a100.txt
# tree_8
# Reading file: output_openACC_v100_run3_tree_8_100000_aa_openacc_v100.txt
# tree_8
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105595084.235052585601807 1.513613509000000 tree_8 run3
# Reading file: output_openACC_v100_run6_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 1.503527084000000 tree_9 run6
# Reading file: output_openACC_a100_run7_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_h200_run10_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 3.552842686000000 tree_9 run10
# Reading file: output_openACC_a100_run5_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_v100_run4_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 1.522460257000000 tree_9 run4
# Reading file: output_openACC_v100_run9_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 2.013871481000000 tree_9 run9
# Reading file: output_openACC_a100_run8_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_h200_run2_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 1.252639060000000 tree_9 run2
# Reading file: output_openACC_h200_run1_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 1.180847881000000 tree_9 run1
# Reading file: output_openACC_a100_run6_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_v100_run7_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 1.616362554000000 tree_9 run7
# Reading file: output_openACC_v100_run5_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 1.614802168000000 tree_9 run5
# Reading file: output_openACC_a100_run4_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_a100_run9_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_v100_run8_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 1.686865054000000 tree_9 run8
# Reading file: output_openACC_a100_run10_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_h200_run3_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 1.375207443000000 tree_9 run3
# Reading file: output_openACC_h200_run5_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 2.278490044000000 tree_9 run5
# Reading file: output_openACC_h200_run8_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 2.436126829000000 tree_9 run8
# Reading file: output_openACC_v100_run3_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 1.458648612000000 tree_9 run3
# Reading file: output_openACC_a100_run2_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_v100_run1_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 1.463629264000000 tree_9 run1
# Reading file: output_openACC_h200_run7_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 2.640279910000000 tree_9 run7
# Reading file: output_openACC_h200_run4_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 1.463451697000000 tree_9 run4
# Reading file: output_openACC_h200_run9_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 3.706426019000000 tree_9 run9
# Reading file: output_openACC_a100_run3_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_v100_run2_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 1.562536434000000 tree_9 run2
# Reading file: output_openACC_v100_run10_tree_9_100000_aa_openacc_v100.txt
# tree_9
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -103328586.881671130657196 2.075614414000000 tree_9 run10
# Reading file: output_openACC_a100_run1_tree_9_100000_aa_openacc_a100.txt
# tree_9
# Reading file: output_openACC_h200_run6_tree_9_100000_aa_openacc_h200.txt
# tree_9
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -103328586.881671130657196 2.566102834000000 tree_9 run6
# Reading file: output_openACC_v100_run4_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.498635814000000 tree_10 run4
# Reading file: output_openACC_h200_run7_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 2.407370135000000 tree_10 run7
# Reading file: output_openACC_h200_run10_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 3.161278257000000 tree_10 run10
# Reading file: output_openACC_a100_run6_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_v100_run10_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 2.011523870000000 tree_10 run10
# Reading file: output_openACC_v100_run9_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.795011110000000 tree_10 run9
# Reading file: output_openACC_h200_run1_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 1.106755603000000 tree_10 run1
# Reading file: output_openACC_v100_run2_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.532744223000000 tree_10 run2
# Reading file: output_openACC_v100_run5_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.672552131000000 tree_10 run5
# Reading file: output_openACC_h200_run6_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 3.115460484000000 tree_10 run6
# Reading file: output_openACC_a100_run1_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_a100_run7_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_v100_run8_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.699197076000000 tree_10 run8
# Reading file: output_openACC_v100_run3_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.486255685000000 tree_10 run3
# Reading file: output_openACC_h200_run5_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 3.014427253000000 tree_10 run5
# Reading file: output_openACC_v100_run6_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.488823105000000 tree_10 run6
# Reading file: output_openACC_a100_run9_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_a100_run10_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_a100_run2_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_a100_run4_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_h200_run8_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 3.311851041000000 tree_10 run8
# Reading file: output_openACC_h200_run3_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 1.875350584000000 tree_10 run3
# Reading file: output_openACC_h200_run4_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 1.638512364000000 tree_10 run4
# Reading file: output_openACC_v100_run7_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.674950749000000 tree_10 run7
# Reading file: output_openACC_a100_run8_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_a100_run3_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_a100_run5_tree_10_100000_aa_openacc_a100.txt
# tree_10
# Reading file: output_openACC_v100_run1_tree_10_100000_aa_openacc_v100.txt
# tree_10
# found a match
# OPENACC
# OPENACC_V100_GPU 1000 100000 100000 -105024958.985804200172424 1.479435319000000 tree_10 run1
# Reading file: output_openACC_h200_run9_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 3.270751721000000 tree_10 run9
# Reading file: output_openACC_h200_run2_tree_10_100000_aa_openacc_h200.txt
# tree_10
# found a match
# OPENACC
# OPENACC_H200_GPU 1000 100000 100000 -105024958.985804200172424 1.553409041000000 tree_10 run2
# Extracted 200 results to /Users/u7826985/Projects/Nvidia/results/2026_02_10_h200_gpu/results.csv

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(output_csv)
# Display the first few rows of the DataFrame
df.head()
# Out:
#             backend  taxa   sites  patterns    likelihood      time treefile  \
# 0  OPENACC_H200_GPU  1000  100000    100000 -1.055493e+08  2.493406   tree_1
# 1  OPENACC_V100_GPU  1000  100000    100000 -1.055493e+08  1.512149   tree_1
# 2  OPENACC_H200_GPU  1000  100000    100000 -1.055493e+08  1.807791   tree_1
# 3  OPENACC_H200_GPU  1000  100000    100000 -1.055493e+08  3.148199   tree_1
# 4  OPENACC_V100_GPU  1000  100000    100000 -1.055493e+08  1.514643   tree_1
#
#   run_number
# 0       run8
# 1       run3
# 2       run5
# 3       run7
# 4       run1

# %%
def plot_min_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    min_times = groups['time'].min().unstack()
    min_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Min Time (s)')
    plt.title('Minimum Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
plot_min_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
plot_average_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
def plot_max_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    max_times = groups['time'].max().unstack()
    max_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Max Time (s)')
    plt.title('Max Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
plot_max_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
plot_average_time_per_backend_v100(df, logy=False, path=f"{cwd}/average_time_per_backend_v100_100taxa_diff_trees_1M_sites_AA.png")

# %%
boxplot_per_tree_group_backend(df)
plot_boxplot_time_per_backend(df, logy=False, path=f"{cwd}/boxplot_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
data = []
read_files_in_directory(f"{results_path}/{DNA_folder}", unique_name="_GPU")
read_files_in_directory(f"{last_results_path}/{DNA_folder}", unique_name="_OLDGPU")
write_to_csv(data, output_csv_aa)
df = pd.read_csv(output_csv_aa)

plot_average_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_DNA.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 2
#       1 data = []
# ----> 2 read_files_in_directory(f"{results_path}/{DNA_folder}", unique_name="_GPU")
#       3 read_files_in_directory(f"{last_results_path}/{DNA_folder}", unique_name="_OLDGPU")
#       4 write_to_csv(data, output_csv_aa)
#
# NameError: name 'DNA_folder' is not defined

# %%
plot_average_time_per_backend_v100(df, logy=False, path=f"{cwd}/average_time_per_backend_v100_100taxa_diff_trees_1M_sites_DNA.png")
