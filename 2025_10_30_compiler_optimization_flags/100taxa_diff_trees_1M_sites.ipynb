# %%
import os
import re
import csv
import numpy as np

# %%
cwd = os.getcwd()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # preapre CSV

# %%
# benchmark_path = "/Users/u7826985/Projects/Nvidia/results/composite_hadamard_optimization"
AA_folder ="100taxa_diff_trees_1M_sites_AA"
DNA_folder ="100taxa_diff_trees_1M_sites"

# %%
last_results_path = "/Users/u7826985/Projects/Nvidia/results/2025_10_20_a100_vs_c100"
results_path = "/Users/u7826985/Projects/Nvidia/results/2025_10_30_compiler_flag"
output_csv = f"{results_path}/results.csv"
output_csv_aa = f"{results_path}/results_aa.csv"

# %%
# Regex to capture the RESULT line
pattern = re.compile(
    r"\[RESULT\]\s*backend=(\w+)\s+taxa=(\d+)\s+sites=(\d+)\s+patterns=(\d+)\s+time=([\d\.e\+\-]+)s\s+likelihood=([\-.\deE]+)"
)

# %%
#read files in results_path

def read_files_in_directory(directory, unique_name=""):
    for i in range(1, 11):
        tree_folder = f"{directory}/tree_{i}"
        files = os.listdir(tree_folder)
        for file in files:
            if file.endswith('.txt'):
                print(f"Reading file: {file}")
                with open(f'{tree_folder}/{file}', 'r') as f:
                    #get treefile name from the txt file name
                    tree_file_name = file.split("_")[4] + "_" + file.split("_")[5]
                    # detect file name contains "a100"
                    run_number = file.split("_")[3]
                    print(tree_file_name)
                    
                    a100 = False
                    transposed = False
                    if "a100" in file.split("_")[-1]:
                        a100 = True
    
                        
                    for line in f:
                        match = pattern.search(line)
                        if match:
                            backend, taxa, sites, patterns, time, likelihood = match.groups()
                            if a100:
                                backend += "_A100"
                            else:
                                backend += "_V100"
                           
                                
                            if taxa != "100":
                                continue
                            backend += unique_name
                            data.append([backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number])
    
                            # Write to CSV
                            # with open(output_csv, 'w', newline='') as csvfile:
                            #     writer = csv.writer(csvfile)
                            #     writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time"])
                            #     writer.writerows(data)

    print(f"Extracted {len(data)} results to {output_csv}")

# %%
alignment_pattern = re.compile(r"Alignment has (\d+) sequences with (\d+) columns, (\d+) distinct patterns")
likelihood_pattern = re.compile(r"Initial log-likelihood:\s+([-0-9.]+).*?took ([0-9.]+) wall-clock sec")

# Data list
# data = []

# %%
# Write to CSV

def write_to_csv(data, output_csv):
    with open(output_csv, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time","treefile", "run_number"])
        writer.writerows(data)

# %%
def plot_average_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    mean_times = groups['time'].mean().unstack()
    mean_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Average Time (s)')
    plt.title('Average Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()


def plot_boxplot_time_per_backend(df, logy=False, path=""):
    plt.figure(figsize=(10, 5))
    df.boxplot(column='time', by='backend')
    if logy:
        plt.yscale('log')
    plt.xlabel('Backend')
    plt.ylabel('Time (s)')
    plt.title('Time Distribution per Backend')
    plt.suptitle('')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()
    
def boxplot_per_tree_group_backend(df):
    # plot per tree file boxplot grouped by backend
    tree_files = df['treefile'].unique()
    for tree_file in tree_files:
        plt.figure(figsize=(10, 5))
        df_tree = df[df['treefile'] == tree_file]
        df_tree.boxplot(column='time', by='backend')
        plt.xlabel('Backend')
        plt.ylabel('Time (s)')
        plt.title(f'Time Distribution per Backend for {tree_file}')
        plt.suptitle('')
        plt.tight_layout()
        plt.show()

# %%
def plot_average_time_per_backend_v100(df, logy=False, path=""):
    # get only v100 backends
    df = df[df['backend'].str.contains('V100')]
    groups = df.groupby(['treefile', 'backend'])
    mean_times = groups['time'].mean().unstack()
    mean_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Average Time (s)')
    plt.title('Average Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %% [markdown]
# # Analysis of Results

# %%
data = []

# %%
# read_files_in_directory(f"{benchmark_path}/{AA_folder}", unique_name="_BENCHMARK")
read_files_in_directory(f"{results_path}/{AA_folder}", unique_name="_GPU")
read_files_in_directory(f"{last_results_path}/{AA_folder}", unique_name="_OLDGPU")

write_to_csv(data, output_csv)
# Out:
# Reading file: output_compiler_flags_run7_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run8_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run3_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run5_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run1_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run6_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run9_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run2_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run10_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run4_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run5_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run1_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run7_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run3_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run8_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run10_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run4_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run6_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run2_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run9_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run2_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run9_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run6_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run10_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run4_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run3_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run8_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run7_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run1_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run5_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run10_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run4_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run9_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run2_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run6_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run1_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run5_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run8_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run3_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run7_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run7_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run3_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run8_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run5_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run1_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run6_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run2_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run9_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run10_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run4_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run5_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run1_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run7_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run8_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run3_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run10_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run4_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run6_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run9_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run2_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run3_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run8_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run7_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run1_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run5_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run2_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run9_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run6_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run10_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run4_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run1_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run5_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run8_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run3_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run7_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run10_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run4_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run9_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run2_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run6_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run6_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run2_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run9_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run10_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run4_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run7_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run3_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run8_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run5_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run1_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run10_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run4_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run6_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run9_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run2_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run5_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run1_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run7_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run8_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run3_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run8_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run3_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run7_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run1_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run5_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run9_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run2_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run6_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run10_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run4_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run1_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run5_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run3_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run8_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run7_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run10_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run4_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run2_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run9_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run6_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run6_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run9_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run2_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run10_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run4_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run7_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run8_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run3_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run5_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run1_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run10_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run4_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run6_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run2_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run9_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run5_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run1_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run7_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run3_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run8_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run4_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run10_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run9_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run2_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run6_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run1_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run5_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run8_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run3_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run7_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run2_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run9_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run6_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run4_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run10_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run3_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run8_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run7_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run1_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run5_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run5_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run1_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run7_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run8_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run3_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run4_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run10_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run6_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run9_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run2_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run7_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run3_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run8_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run5_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run1_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run6_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run2_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run9_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run4_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run10_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run2_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run1_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run3_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run9_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run4_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run6_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run10_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run8_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run7_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run5_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run1_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run3_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run2_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run10_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run8_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run7_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run5_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run9_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run4_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run6_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Extracted 200 results to /Users/u7826985/Projects/Nvidia/results/2025_10_30_compiler_flag/results.csv
# Reading file: output_a100v100_comp_run7_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run8_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run3_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run5_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run1_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run6_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run10_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run9_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run2_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run4_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run5_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run1_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run7_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run3_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run8_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run4_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run6_tree_1_1000000_aa_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run10_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run2_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run9_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run10_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run2_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run9_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run6_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run4_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run3_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run8_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run7_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run1_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run5_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run4_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run10_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run9_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run2_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run6_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run1_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run5_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run8_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run3_tree_2_1000000_aa_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run7_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run7_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run3_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run8_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run5_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run1_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run6_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run10_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run2_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run9_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run4_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run5_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run1_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run7_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run8_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run3_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run4_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run6_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run10_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run9_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run2_tree_3_1000000_aa_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run3_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run8_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run7_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run1_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run5_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run10_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run2_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run9_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run6_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run4_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run1_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run5_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run8_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run3_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run7_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run4_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run10_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run9_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run2_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run6_tree_4_1000000_aa_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run6_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run10_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run2_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run9_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run4_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run7_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run3_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run8_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run5_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run1_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run4_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run6_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run10_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run9_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run2_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run5_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run1_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run7_tree_5_1000000_aa_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run8_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run3_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run8_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run3_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run7_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run1_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run5_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run10_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run9_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run2_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run6_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run4_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run1_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run5_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run3_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run8_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run7_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run4_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run10_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run2_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run9_tree_6_1000000_aa_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run6_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run6_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run10_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run9_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run2_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run4_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run7_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run8_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run3_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run5_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run1_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run4_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run6_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run10_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run2_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run9_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run5_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run1_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run7_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run3_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run8_tree_7_1000000_aa_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run4_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run9_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run2_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run10_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run6_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run1_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run5_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run8_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run3_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run7_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run2_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run9_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run10_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run6_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run4_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run3_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run8_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run7_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run1_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run5_tree_8_1000000_aa_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run5_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run1_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run7_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run8_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run3_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run4_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run6_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run9_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run2_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run10_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run7_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run3_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run8_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run5_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run1_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run6_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run2_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run9_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run10_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run4_tree_9_1000000_aa_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run1_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run3_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run2_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run7_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run5_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run10_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run8_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run4_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run6_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run9_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run2_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run1_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run3_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run4_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run6_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run9_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run7_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run5_tree_10_1000000_aa_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run10_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run8_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# Extracted 400 results to /Users/u7826985/Projects/Nvidia/results/2025_10_30_compiler_flag/results.csv

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(output_csv)
# Display the first few rows of the DataFrame
df.head()
# Out:
#             backend  taxa    sites  patterns    likelihood      time treefile  \
# 0  OPENACC_A100_GPU   100  1000000   1000000 -1.104132e+08  1.224826   tree_1
# 1  OPENACC_V100_GPU   100  1000000   1000000 -1.104132e+08  1.191210   tree_1
# 2  OPENACC_V100_GPU   100  1000000   1000000 -1.104132e+08  1.439221   tree_1
# 3  OPENACC_V100_GPU   100  1000000   1000000 -1.104132e+08  1.301763   tree_1
# 4  OPENACC_A100_GPU   100  1000000   1000000 -1.104132e+08  1.352566   tree_1
#
#   run_number
# 0       run7
# 1       run8
# 2       run3
# 3       run5
# 4       run1

# %%
plot_average_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
plot_average_time_per_backend_v100(df, logy=False, path=f"{cwd}/average_time_per_backend_v100_100taxa_diff_trees_1M_sites_AA.png")

# %%
boxplot_per_tree_group_backend(df)
plot_boxplot_time_per_backend(df, logy=False, path=f"{cwd}/boxplot_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
data = []
read_files_in_directory(f"{results_path}/{DNA_folder}", unique_name="_GPU")
read_files_in_directory(f"{last_results_path}/{DNA_folder}", unique_name="_OLDGPU")
write_to_csv(data, output_csv_aa)
df = pd.read_csv(output_csv_aa)

plot_average_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_DNA.png")
# Out:
# Reading file: output_compiler_flags_run2_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run3_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run1_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run9_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run6_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run4_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run8_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run10_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run5_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run7_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run3_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run1_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run2_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run8_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run10_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run5_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run7_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run9_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run6_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_compiler_flags_run4_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_compiler_flags_run3_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run1_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run2_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run5_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run7_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run8_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run10_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run6_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run4_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run9_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run2_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run3_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run1_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run6_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run4_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run9_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run5_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_compiler_flags_run7_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run8_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run10_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_compiler_flags_run7_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run5_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run10_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run8_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run4_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run6_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run9_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run1_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run3_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run2_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run4_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run6_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run9_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run7_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run5_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run10_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run8_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run2_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run1_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_compiler_flags_run3_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_compiler_flags_run4_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run6_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run9_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run7_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run5_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run10_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run8_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run2_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run1_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run3_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run7_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run5_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run10_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run8_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run4_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run6_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run9_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run1_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run3_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_compiler_flags_run2_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_compiler_flags_run2_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run3_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run1_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run6_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run4_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run9_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run5_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run7_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run8_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run10_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run3_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run1_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run2_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run5_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run7_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run8_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run10_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run6_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run4_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_compiler_flags_run9_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_compiler_flags_run3_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run1_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run2_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run8_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run10_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run5_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run7_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run9_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run6_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run4_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run2_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run3_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run1_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run9_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run6_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run4_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run8_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run10_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run5_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_compiler_flags_run7_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_compiler_flags_run10_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run8_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run7_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run5_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run9_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run4_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run6_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run1_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run3_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run2_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run9_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run4_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run6_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run10_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run8_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run7_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run5_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run2_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run1_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_compiler_flags_run3_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_compiler_flags_run3_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run1_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run2_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run8_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run10_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run5_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run7_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run9_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run6_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run4_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run2_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run3_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run1_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run9_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run6_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run4_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run8_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run10_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run5_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_compiler_flags_run7_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_compiler_flags_run10_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run8_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run7_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run5_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run9_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run4_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run6_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run1_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run3_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run2_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run9_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run4_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run6_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run10_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run8_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run7_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run5_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run2_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run1_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_compiler_flags_run3_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_compiler_flags_run9_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run7_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run8_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run1_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run6_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run2_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run5_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run10_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run3_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run4_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run8_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run6_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run1_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run9_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run7_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_compiler_flags_run10_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run4_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run3_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run5_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_compiler_flags_run2_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Extracted 200 results to /Users/u7826985/Projects/Nvidia/results/2025_10_30_compiler_flag/results.csv
# Reading file: output_a100v100_comp_run3_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run1_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run2_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run5_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run7_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run8_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run10_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run6_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run4_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run9_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run2_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run3_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run1_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run6_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run4_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run9_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run5_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# Reading file: output_a100v100_comp_run7_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run8_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run10_tree_1_1000000_dna_openacc_a100.txt
# tree_1
# Reading file: output_a100v100_comp_run2_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run3_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run1_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run9_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run6_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run4_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run8_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run10_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run5_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run7_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run3_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run1_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run2_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run8_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run10_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run5_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run7_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run9_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run6_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# Reading file: output_a100v100_comp_run4_tree_2_1000000_dna_openacc_a100.txt
# tree_2
# Reading file: output_a100v100_comp_run9_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run4_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run6_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run10_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run8_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run7_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run5_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run2_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run1_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run3_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run10_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run8_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run7_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run5_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run9_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run4_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run6_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run1_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run3_tree_3_1000000_dna_openacc_a100.txt
# tree_3
# Reading file: output_a100v100_comp_run2_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# Reading file: output_a100v100_comp_run10_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run8_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run7_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run5_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run9_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run4_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run6_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run1_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run3_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run2_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run9_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run4_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run6_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run10_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run8_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run7_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run5_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run2_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run1_tree_4_1000000_dna_openacc_a100.txt
# tree_4
# Reading file: output_a100v100_comp_run3_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# Reading file: output_a100v100_comp_run3_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run1_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run2_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run8_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run10_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run5_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run7_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run9_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run6_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run4_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run2_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run3_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run1_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run9_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run6_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run4_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run8_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run10_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run5_tree_5_1000000_dna_openacc_a100.txt
# tree_5
# Reading file: output_a100v100_comp_run7_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# Reading file: output_a100v100_comp_run2_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run3_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run1_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run6_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run4_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run9_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run5_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run7_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run8_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run10_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run3_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run1_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run2_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run5_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run7_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run8_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run10_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run6_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run4_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# Reading file: output_a100v100_comp_run9_tree_6_1000000_dna_openacc_a100.txt
# tree_6
# Reading file: output_a100v100_comp_run4_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run6_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run9_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run7_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run5_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run10_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run8_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run2_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run1_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run3_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run7_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run5_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run10_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run8_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run4_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run6_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run9_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run1_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run3_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# Reading file: output_a100v100_comp_run2_tree_7_1000000_dna_openacc_a100.txt
# tree_7
# Reading file: output_a100v100_comp_run2_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run3_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run1_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run6_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run4_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run9_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run5_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run7_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run8_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run10_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run3_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run1_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run2_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run5_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run7_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run8_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run10_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run6_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run4_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# Reading file: output_a100v100_comp_run9_tree_8_1000000_dna_openacc_a100.txt
# tree_8
# Reading file: output_a100v100_comp_run4_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run6_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run9_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run7_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run5_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run10_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run8_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run2_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run1_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run3_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run7_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run5_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run10_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run8_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run4_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run6_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run9_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run1_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run3_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# Reading file: output_a100v100_comp_run2_tree_9_1000000_dna_openacc_a100.txt
# tree_9
# Reading file: output_a100v100_comp_run1_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run6_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run8_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run7_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run10_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run9_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run3_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run4_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run2_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run5_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run7_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run10_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run9_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run6_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run1_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# Reading file: output_a100v100_comp_run8_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run5_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run2_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run4_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Reading file: output_a100v100_comp_run3_tree_10_1000000_dna_openacc_a100.txt
# tree_10
# Extracted 400 results to /Users/u7826985/Projects/Nvidia/results/2025_10_30_compiler_flag/results.csv

# %%
plot_average_time_per_backend_v100(df, logy=False, path=f"{cwd}/average_time_per_backend_v100_100taxa_diff_trees_1M_sites_DNA.png")
