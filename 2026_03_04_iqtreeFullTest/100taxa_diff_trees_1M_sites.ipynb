# %%
import os
import re
import csv
import numpy as np

# %%
cwd = os.getcwd()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # preapre CSV

# %%
# benchmark_path = "/Users/u7826985/Projects/Nvidia/results/composite_hadamard_optimization"
AA_folder ="100taxa_diff_trees_1M_sites_AA"
DNA_folder ="100taxa_diff_trees_1M_sites"

# %%
results_path = "/Users/u7826985/Projects/Nvidia/results/2026_03_04_wholetest"

output_csv = f"{results_path}/results.csv"
output_csv_aa = f"{results_path}/results_aa.csv"

# %%
# Regex to capture the RESULT line
pattern = re.compile(
    r"\[RESULT\]\s*backend=(\w+)\s+taxa=(\d+)\s+sites=(\d+)\s+patterns=(\d+)\s+time=([\d\.e\+\-]+)s\s+likelihood=([\-.\deE]+)"
)

# %%
#read files in results_path

def read_files_in_las_reults_directory(directory, unique_name=""):
    for i in range(1, 11):
        tree_folder = f"{directory}/tree_{i}"
        files = os.listdir(tree_folder)
        op_type=""
        for file in files:
            if file.startswith("output_v100_cudaCublas_run"):
                op_type="CUDA_OLD"
            elif (file.startswith("output_v100_openACC_run") or file.startswith("output_v100_OpenACC_run")):
                op_type="OpenACC"
            else:
                continue
            if file.endswith('.txt'):
                print(f"Reading file: {file}")
                with open(f'{tree_folder}/{file}', 'r') as f:
                    #get treefile name from the txt file name
                    tree_file_name = file.split("_")[4] + "_" + file.split("_")[5]
                    # detect file name contains "a100"
                    run_number = file.split("_")[3]
                    print(tree_file_name)
                    
                    
                    
                    h200 = False
                    a100 = False
                    transposed = False
                    if "h200" in file.split("_")[-1]:
                        h200 = True
                    
                    elif "a100" in file.split("_")[-1]:
                        a100 = True
                        continue
                        
                    for line in f:
                        match = pattern.search(line)
                        if match:
                            print("found a match")
                            backend, taxa, sites, patterns, time, likelihood = match.groups()
                            backend = op_type
                            print(backend)
                            if h200:
                                backend += "_H200"
                            elif a100:
                                backend += "_A100"
                            else:
                                backend += "_V100"
                           
                                
                            # if taxa != "100":
                            #     continue
                            # backend = op_type
                            data.append([backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number])
                            
                            print(backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number)
    
                            # Write to CSV
                            # with open(output_csv, 'w', newline='') as csvfile:
                            #     writer = csv.writer(csvfile)
                            #     writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time"])
                            #     writer.writerows(data)

    print(f"Extracted {len(data)} results to {output_csv}")

# %%
#read files in results_path

def read_files_in_directory(directory, unique_name=""):
    for i in range(1, 11):
        tree_folder = f"{directory}/tree_{i}"
        files = os.listdir(tree_folder)

        for file in files:
            
            if file.endswith('.txt'):
                print(f"Reading file: {file}")
                with open(f'{tree_folder}/{file}', 'r') as f:
                    #get treefile name from the txt file name
                    tree_file_name = file.split("_")[4] + "_" + file.split("_")[5]
                    # detect file name contains "a100"
                    run_number = file.split("_")[3]
                    print(tree_file_name)
                    
                    
                    
                    h200 = False
                    a100 = False
                    transposed = False
                    if "h200" in file.split("_")[-1]:
                        h200 = True
                    
                    elif "a100" in file.split("_")[-1]:
                        a100 = True
                        continue
                        
                    for line in f:
                        match = pattern.search(line)
                        if match:
                            print("found a match")
                            backend, taxa, sites, patterns, time, likelihood = match.groups()
                            backend = "OpenACC"
                            print(backend)
                            if h200:
                                backend += "_H200"
                            elif a100:
                                backend += "_A100"
                            else:
                                backend += "_V100"
                           
                                
                            # if taxa != "100":
                            #     continue
                            # backend = op_type
                            data.append([backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number])
                            
                            print(backend, taxa, sites, patterns, likelihood, time, tree_file_name, run_number)
    
                            # Write to CSV
                            # with open(output_csv, 'w', newline='') as csvfile:
                            #     writer = csv.writer(csvfile)
                            #     writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time"])
                            #     writer.writerows(data)

    print(f"Extracted {len(data)} results to {output_csv}")

# %%
alignment_pattern = re.compile(r"Alignment has (\d+) sequences with (\d+) columns, (\d+) distinct patterns")
likelihood_pattern = re.compile(r"Initial log-likelihood:\s+([-0-9.]+)")
params_opt_pattern = re.compile(r"Parameters optimization took \d+ rounds? \(([0-9.]+) sec\)")
wallclock_pattern = re.compile(r"Total wall-clock time used:\s+([0-9.]+)\s+sec")
likelihood_pattern_clock = re.compile(r"Initial log-likelihood:\s+([-0-9.]+).*?took ([0-9.]+) wall-clock sec")

# %%
# Write to CSV

def write_to_csv(data, output_csv):
    with open(output_csv, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["backend", "taxa", "sites", "patterns", "likelihood", "time","treefile", "run_number"])
        writer.writerows(data)

# %%
def plot_average_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    mean_times = groups['time'].mean().unstack()
    mean_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Average Time (s)')
    plt.title('Average Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()


def plot_boxplot_time_per_backend(df, logy=False, path=""):
    plt.figure(figsize=(10, 5))
    df.boxplot(column='time', by='backend')
    if logy:
        plt.yscale('log')
    plt.xlabel('Backend')
    plt.ylabel('Time (s)')
    plt.title('Time Distribution per Backend')
    plt.suptitle('')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()
    
def boxplot_per_tree_group_backend(df):
    # plot per tree file boxplot grouped by backend
    tree_files = df['treefile'].unique()
    for tree_file in tree_files:
        plt.figure(figsize=(10, 5))
        df_tree = df[df['treefile'] == tree_file]
        df_tree.boxplot(column='time', by='backend')
        plt.xlabel('Backend')
        plt.ylabel('Time (s)')
        plt.title(f'Time Distribution per Backend for {tree_file}')
        plt.suptitle('')
        plt.tight_layout()
        plt.show()

# %%
def plot_average_time_per_backend_v100(df, logy=False, path=""):
    # get only v100 backends
    df = df[df['backend'].str.contains('V100')]
    groups = df.groupby(['treefile', 'backend'])
    mean_times = groups['time'].mean().unstack()
    mean_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Average Time (s)')
    plt.title('Average Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
def plot_runtime_boxplot_auto(
    df,
    tree_col=None,
    backend_col=None,
    time_col=None,
    backend_cols=None,          # for wide format: list of backend columns
    figsize=(14, 6),
    show_outliers=True,
    title="Runtime Distribution per Tree per Backend",
    rotate_xticks=45,
    path=""
):
    """
    Auto boxplot for runtime vs tree grouped by backend.
    Works with:
      - LONG format: [tree, backend, time]
      - WIDE format: [tree, CUDA_V100, OpenACC_V100, ...] (multiple runs/rows per tree)
    """

    df = df.copy()

    # ---- 1) Detect columns if not provided ----
    cols = list(df.columns)

    # Guess tree column
    if tree_col is None:
        for c in cols:
            lc = c.lower()
            if lc in ("tree", "tree_file", "treefile", "tree_id", "treeid", "file"):
                tree_col = c
                break
        if tree_col is None:
            # fallback: first non-numeric column
            non_numeric = [c for c in cols if not pd.api.types.is_numeric_dtype(df[c])]
            tree_col = non_numeric[0] if non_numeric else cols[0]

    # If user explicitly gave wide backend columns, treat as wide
    if backend_cols is not None:
        wide_backend_cols = backend_cols
    else:
        wide_backend_cols = None

    # Determine if long format is available
    has_long = (
        (backend_col is not None and backend_col in df.columns) or
        any(c.lower() in ("backend", "impl", "implementation") for c in cols)
    ) and (
        (time_col is not None and time_col in df.columns) or
        any(c.lower() in ("time", "runtime", "elapsed", "elapsed_time", "seconds", "sec", "min_time") for c in cols)
    )

    # ---- 2) If long-format, use it ----
    if has_long:
        if backend_col is None:
            backend_col = next(c for c in cols if c.lower() in ("backend", "impl", "implementation"))
        if time_col is None:
            time_col = next(c for c in cols if c.lower() in ("time", "runtime", "elapsed", "elapsed_time", "seconds", "sec", "min_time"))

        plot_df = df[[tree_col, backend_col, time_col]].copy()
        plot_df[time_col] = pd.to_numeric(plot_df[time_col], errors="coerce")
        plot_df = plot_df.dropna(subset=[time_col])

        x, y, h = tree_col, time_col, backend_col

    # ---- 3) Otherwise assume wide-format and melt ----
    else:
        if wide_backend_cols is None:
            # pick numeric columns excluding the tree column as backend columns
            wide_backend_cols = [c for c in cols if c != tree_col]
            # keep only columns that look numeric-ish after coercion
            keep = []
            for c in wide_backend_cols:
                s = pd.to_numeric(df[c], errors="coerce")
                if s.notna().any():
                    keep.append(c)
            wide_backend_cols = keep

        if not wide_backend_cols:
            raise ValueError(
                f"Couldn't infer backend/time columns.\n"
                f"Columns seen: {cols}\n"
                f"Try providing: backend_cols=[...], and tree_col='...'"
            )

        plot_df = df[[tree_col] + wide_backend_cols].copy()
        plot_df = plot_df.melt(id_vars=[tree_col], value_vars=wide_backend_cols,
                               var_name="backend", value_name="time")
        plot_df["time"] = pd.to_numeric(plot_df["time"], errors="coerce")
        plot_df = plot_df.dropna(subset=["time"])

        x, y, h = tree_col, "time", "backend"

    # ---- 4) Plot ----
    plt.figure(figsize=figsize)
    sns.boxplot(data=plot_df, x=x, y=y, hue=h, showfliers=show_outliers)

    plt.title(title)
    plt.xlabel("Tree File")
    plt.ylabel("Time (s)")
    plt.xticks(rotation=rotate_xticks)
    plt.legend(title="Backend")
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

    # helpful debug info
    print("Using columns ->", {"tree": x, "backend": h, "time": y})
    print("Rows plotted:", len(plot_df))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_bar_with_box(df,
                      tree_col="treefile",
                      time_col="time",
                      backend_col="backend",
                      figsize=(14,6), path=""):
    """
    Plots boxplot (distribution) with mean bar overlay.
    """

    plt.figure(figsize=figsize)

    # --- Boxplot (distribution) ---
    sns.boxplot(
        data=df,
        x=tree_col,
        y=time_col,
        hue=backend_col,
        showfliers=False,
        linewidth=1
    )

    # --- Barplot (mean overlay) ---
    sns.barplot(
        data=df,
        x=tree_col,
        y=time_col,
        hue=backend_col,
        estimator="mean",
        errorbar=None,
        alpha=0.4,
        dodge=True
    )

    plt.title("Runtime Distribution + Mean per Tree per Backend")
    plt.xticks(rotation=45)
    plt.ylabel("Time (s)")
    plt.xlabel("Tree File")

    # Fix duplicate legends (because both plots create one)
    handles, labels = plt.gca().get_legend_handles_labels()
    n = len(df[backend_col].unique())
    plt.legend(handles[:n], labels[:n], title="Backend")

    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
def read_iqtree_results(directory, unique="", skip=False):
    for i in range(1, 11):
        tree_folder = f"{directory}/tree_{i}"
        files = os.listdir(tree_folder)
        for file in files:
            if file.endswith('.log'):
                print(f"Reading IQ-TREE file: {file}")
                with open(f'{tree_folder}/{file}', 'r') as f:
                    content = f.read()
                    # filename: output_test_iqtree_OPENACC_run1_tree_1_1000000_iqtree.log
                    #           output_test_iqtree_VANILA_run1_tree_1_1000000_aa_iqtree.log
                    parts = file.split("_")
                    extype = parts[3]           # OPENACC or VANILA
                    print(extype)
                    run_number = parts[4]        # run1, run2, ...
                    tree_file = parts[5] + "_" + parts[6]  # tree_1, tree_2, ...

                    # Extract alignment info
                    aln_match = alignment_pattern.search(content)
                    ll_match = likelihood_pattern.search(content)
                    opt_match = params_opt_pattern.search(content)
                    

                    if aln_match and ll_match and opt_match:
                        taxa = int(aln_match.group(1))
                        sites = int(aln_match.group(2))
                        patterns = int(aln_match.group(3))
                        likelihood = float(ll_match.group(1))
                        time = float(opt_match.group(1))
                        backend=extype
                        print(extype)
                        if extype != "VANILA":
                            backend = f"IQ-TREE_GPU_V100"
                            # if skip:
                            #     continue
                        else:
                            print("here")
                            if "10CPU" in file:
                                backend = "IQ-TREE_CPU_10_CORES"
                            else:
                                backend = "IQ-TREE_CPU_1_CORE"

                        data.append([backend, taxa, sites, patterns, likelihood, time, tree_file, run_number])

    print(f"Extracted {len(data)} IQ-TREE results")

# %% [markdown]
# # Analysis of Results

# %%
data = []

# %%
# read_files_in_directory(f"{benchmark_path}/{AA_folder}", unique_name="_BENCHMARK")
read_files_in_directory(f"{results_path}/{AA_folder}", unique_name="_GPU")
read_iqtree_results(f"{results_path}/{AA_folder}")

write_to_csv(data, output_csv)
# Out:
# Reading file: output_poc_openACC_run9_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.302388615000000 tree_1 run9
# Reading file: output_poc_openACC_run2_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.327171527000000 tree_1 run2
# Reading file: output_poc_openACC_run10_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.275145033000000 tree_1 run10
# Reading file: output_poc_openACC_run4_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.288577450000000 tree_1 run4
# Reading file: output_poc_openACC_run8_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.311187336000000 tree_1 run8
# Reading file: output_poc_openACC_run3_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.286583574000000 tree_1 run3
# Reading file: output_poc_openACC_run5_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.310765900000000 tree_1 run5
# Reading file: output_poc_openACC_run6_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.293595962000000 tree_1 run6
# Reading file: output_poc_openACC_run1_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.305870288000000 tree_1 run1
# Reading file: output_poc_openACC_run7_tree_1_1000000_aa_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -110413195.778517276048660 1.364586241000000 tree_1 run7
# Reading file: output_poc_openACC_run7_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.311550095000000 tree_2 run7
# Reading file: output_poc_openACC_run1_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.256559478000000 tree_2 run1
# Reading file: output_poc_openACC_run6_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.251220481000000 tree_2 run6
# Reading file: output_poc_openACC_run5_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.305578037000000 tree_2 run5
# Reading file: output_poc_openACC_run8_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.321518561000000 tree_2 run8
# Reading file: output_poc_openACC_run3_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.262733880000000 tree_2 run3
# Reading file: output_poc_openACC_run4_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.245396171000000 tree_2 run4
# Reading file: output_poc_openACC_run10_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.256139040000000 tree_2 run10
# Reading file: output_poc_openACC_run9_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.283290203000000 tree_2 run9
# Reading file: output_poc_openACC_run2_tree_2_1000000_aa_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -99186349.700422123074532 1.439183019000000 tree_2 run2
# Reading file: output_poc_openACC_run6_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.253666790000000 tree_3 run6
# Reading file: output_poc_openACC_run7_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.285817191000000 tree_3 run7
# Reading file: output_poc_openACC_run1_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.309499908000000 tree_3 run1
# Reading file: output_poc_openACC_run10_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.271769885000000 tree_3 run10
# Reading file: output_poc_openACC_run4_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.267104878000000 tree_3 run4
# Reading file: output_poc_openACC_run9_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.272670646000000 tree_3 run9
# Reading file: output_poc_openACC_run2_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.288354100000000 tree_3 run2
# Reading file: output_poc_openACC_run5_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.279709645000000 tree_3 run5
# Reading file: output_poc_openACC_run8_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.283042739000000 tree_3 run8
# Reading file: output_poc_openACC_run3_tree_3_1000000_aa_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -112041381.325586110353470 1.258768826000000 tree_3 run3
# Reading file: output_poc_openACC_run2_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.277823829000000 tree_4 run2
# Reading file: output_poc_openACC_run9_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.269090509000000 tree_4 run9
# Reading file: output_poc_openACC_run4_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.261547161000000 tree_4 run4
# Reading file: output_poc_openACC_run10_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.309663347000000 tree_4 run10
# Reading file: output_poc_openACC_run3_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.243521704000000 tree_4 run3
# Reading file: output_poc_openACC_run8_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.302944541000000 tree_4 run8
# Reading file: output_poc_openACC_run5_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.283086030000000 tree_4 run5
# Reading file: output_poc_openACC_run6_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.297982508000000 tree_4 run6
# Reading file: output_poc_openACC_run1_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.314056721000000 tree_4 run1
# Reading file: output_poc_openACC_run7_tree_4_1000000_aa_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -97277284.227406084537506 1.323579319000000 tree_4 run7
# Reading file: output_poc_openACC_run3_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.258804353000000 tree_5 run3
# Reading file: output_poc_openACC_run8_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.293265865000000 tree_5 run8
# Reading file: output_poc_openACC_run5_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.306808313000000 tree_5 run5
# Reading file: output_poc_openACC_run2_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.301805560000000 tree_5 run2
# Reading file: output_poc_openACC_run9_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.267104058000000 tree_5 run9
# Reading file: output_poc_openACC_run10_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.316290532000000 tree_5 run10
# Reading file: output_poc_openACC_run4_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.263986415000000 tree_5 run4
# Reading file: output_poc_openACC_run1_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.304147424000000 tree_5 run1
# Reading file: output_poc_openACC_run7_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.302882691000000 tree_5 run7
# Reading file: output_poc_openACC_run6_tree_5_1000000_aa_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -109757143.329428479075432 1.278948374000000 tree_5 run6
# Reading file: output_poc_openACC_run6_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.281992505000000 tree_6 run6
# Reading file: output_poc_openACC_run7_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.285676567000000 tree_6 run7
# Reading file: output_poc_openACC_run1_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.299262089000000 tree_6 run1
# Reading file: output_poc_openACC_run4_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.271661594000000 tree_6 run4
# Reading file: output_poc_openACC_run10_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.242115564000000 tree_6 run10
# Reading file: output_poc_openACC_run2_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.322575486000000 tree_6 run2
# Reading file: output_poc_openACC_run9_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.271784585000000 tree_6 run9
# Reading file: output_poc_openACC_run5_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.274868523000000 tree_6 run5
# Reading file: output_poc_openACC_run3_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.251362895000000 tree_6 run3
# Reading file: output_poc_openACC_run8_tree_6_1000000_aa_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -102915332.041291579604149 1.288160235000000 tree_6 run8
# Reading file: output_poc_openACC_run7_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.297251731000000 tree_7 run7
# Reading file: output_poc_openACC_run1_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.292648375000000 tree_7 run1
# Reading file: output_poc_openACC_run6_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.308597765000000 tree_7 run6
# Reading file: output_poc_openACC_run5_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.319626625000000 tree_7 run5
# Reading file: output_poc_openACC_run3_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.253395974000000 tree_7 run3
# Reading file: output_poc_openACC_run8_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.306427142000000 tree_7 run8
# Reading file: output_poc_openACC_run10_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.278454210000000 tree_7 run10
# Reading file: output_poc_openACC_run4_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.261751709000000 tree_7 run4
# Reading file: output_poc_openACC_run2_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.271221878000000 tree_7 run2
# Reading file: output_poc_openACC_run9_tree_7_1000000_aa_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -104636698.409147098660469 1.258939317000000 tree_7 run9
# Reading file: output_poc_openACC_run1_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.278041000000000 tree_8 run1
# Reading file: output_poc_openACC_run7_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.290004962000000 tree_8 run7
# Reading file: output_poc_openACC_run6_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.278038644000000 tree_8 run6
# Reading file: output_poc_openACC_run3_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.247117530000000 tree_8 run3
# Reading file: output_poc_openACC_run8_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.313375400000000 tree_8 run8
# Reading file: output_poc_openACC_run5_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.276211331000000 tree_8 run5
# Reading file: output_poc_openACC_run2_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.321115823000000 tree_8 run2
# Reading file: output_poc_openACC_run9_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.277968869000000 tree_8 run9
# Reading file: output_poc_openACC_run4_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.258210549000000 tree_8 run4
# Reading file: output_poc_openACC_run10_tree_8_1000000_aa_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106825444.951877132058144 1.241840700000000 tree_8 run10
# Reading file: output_poc_openACC_run6_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.382226964000000 tree_9 run6
# Reading file: output_poc_openACC_run1_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.332515404000000 tree_9 run1
# Reading file: output_poc_openACC_run7_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.296220849000000 tree_9 run7
# Reading file: output_poc_openACC_run2_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.312016288000000 tree_9 run2
# Reading file: output_poc_openACC_run9_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.398297366000000 tree_9 run9
# Reading file: output_poc_openACC_run10_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.244451030000000 tree_9 run10
# Reading file: output_poc_openACC_run4_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.303152616000000 tree_9 run4
# Reading file: output_poc_openACC_run3_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.287375675000000 tree_9 run3
# Reading file: output_poc_openACC_run8_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.270787938000000 tree_9 run8
# Reading file: output_poc_openACC_run5_tree_9_1000000_aa_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -95332589.209261104464531 1.309829729000000 tree_9 run5
# Reading file: output_poc_openACC_run4_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.261991377000000 tree_10 run4
# Reading file: output_poc_openACC_run8_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.287815735000000 tree_10 run8
# Reading file: output_poc_openACC_run7_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.304093702000000 tree_10 run7
# Reading file: output_poc_openACC_run10_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.228375903000000 tree_10 run10
# Reading file: output_poc_openACC_run2_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.281924148000000 tree_10 run2
# Reading file: output_poc_openACC_run1_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.294907807000000 tree_10 run1
# Reading file: output_poc_openACC_run5_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.326234514000000 tree_10 run5
# Reading file: output_poc_openACC_run9_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.277444533000000 tree_10 run9
# Reading file: output_poc_openACC_run6_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.299974158000000 tree_10 run6
# Reading file: output_poc_openACC_run3_tree_10_1000000_aa_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -106559017.964738756418228 1.313344937000000 tree_10 run3
# Extracted 100 results to /Users/u7826985/Projects/Nvidia/results/2026_03_04_wholetest/results.csv
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_1_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_1_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_1_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_2_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_2_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_2_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_3_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_3_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_3_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_4_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_4_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_4_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_5_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_5_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_5_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_6_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_6_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_6_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_7_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_7_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_7_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_8_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_8_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_8_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_9_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_9_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_9_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run8_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run4_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run2_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run9_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run3_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run5_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run10_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run6_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run1_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThreads_VANILA_run7_tree_10_1000000_aa_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_10_1000000_aa_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_10_1000000_aa_iqtree.log
# VANILA
# VANILA
# here
# Extracted 400 IQ-TREE results

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(output_csv)
# Display the first few rows of the DataFrame
df
# Out:
#                   backend  taxa    sites  patterns    likelihood       time  \
# 0            OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.302389
# 1            OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.327172
# 2            OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.275145
# 3            OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.288577
# 4            OpenACC_V100   100  1000000   1000000 -1.104132e+08   1.311187
# ..                    ...   ...      ...       ...           ...        ...
# 395    IQ-TREE_CPU_1_CORE   100  1000000   1000000 -1.065590e+08  13.414000
# 396  IQ-TREE_CPU_10_CORES   100  1000000   1000000 -1.065590e+08   1.574000
# 397      IQ-TREE_GPU_V100   100  1000000   1000000 -1.065590e+08   6.885000
# 398      IQ-TREE_GPU_V100   100  1000000   1000000 -1.065590e+08   6.882000
# 399    IQ-TREE_CPU_1_CORE   100  1000000   1000000 -1.065590e+08  13.119000
#
#     treefile run_number
# 0     tree_1       run9
# 1     tree_1       run2
# 2     tree_1      run10
# 3     tree_1       run4
# 4     tree_1       run8
# ..       ...        ...
# 395  tree_10       run4
# 396  tree_10       run7
# 397  tree_10       run9
# 398  tree_10       run1
# 399  tree_10       run3
#
# [400 rows x 8 columns]

# %%
plot_runtime_boxplot_auto(df, path=f"{cwd}/aa_boxonly.png")
# Out:
# Using columns -> {'tree': 'treefile', 'backend': 'backend', 'time': 'time'}
# Rows plotted: 400

# %%
plot_bar_with_box(df, path=f"{cwd}/aa_boxplot.png")

# %%
def plot_min_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    min_times = groups['time'].min().unstack()
    min_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Min Time (s)')
    plt.title('Minimum Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
plot_min_time_per_backend(df, logy=False, path=f"{cwd}/min_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
plot_average_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
def plot_max_time_per_backend(df, logy=False, path=""):
    groups = df.groupby(['treefile', 'backend'])
    max_times = groups['time'].max().unstack()
    max_times.plot(kind='bar', figsize=(10, 5))
    if logy:
        plt.yscale('log')
    plt.xlabel('Tree File')
    plt.ylabel('Max Time (s)')
    plt.title('Max Time per Backend for Each Tree File')
    plt.tight_layout()
    if path:
        plt.savefig(path)
    plt.show()

# %%
plot_max_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
# boxplot_per_tree_group_backend(df)
# plot_boxplot_time_per_backend(df, logy=False, path=f"{cwd}/boxplot_time_per_backend_100taxa_diff_trees_1M_sites_AA.png")

# %%
data = []
read_files_in_directory(f"{results_path}/{DNA_folder}", unique_name="_GPU")
read_iqtree_results(f"{results_path}/{DNA_folder}")
write_to_csv(data, output_csv_aa)
df = pd.read_csv(output_csv_aa)
# Out:
# Reading file: output_poc_openACC_run9_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.233555062000000 tree_1 run9
# Reading file: output_poc_openACC_run6_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.206463880000000 tree_1 run6
# Reading file: output_poc_openACC_run5_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.210843397000000 tree_1 run5
# Reading file: output_poc_openACC_run3_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.232883739000000 tree_1 run3
# Reading file: output_poc_openACC_run8_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.373047046000000 tree_1 run8
# Reading file: output_poc_openACC_run7_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.254217372000000 tree_1 run7
# Reading file: output_poc_openACC_run4_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.196718498000000 tree_1 run4
# Reading file: output_poc_openACC_run1_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.225989556000000 tree_1 run1
# Reading file: output_poc_openACC_run10_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.196531033000000 tree_1 run10
# Reading file: output_poc_openACC_run2_tree_1_1000000_dna_openacc_v100.txt
# tree_1
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -70051678.096398830413818 1.285801555000000 tree_1 run2
# Reading file: output_poc_openACC_run5_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.176045418000000 tree_2 run5
# Reading file: output_poc_openACC_run6_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.183360422000000 tree_2 run6
# Reading file: output_poc_openACC_run9_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.209013956000000 tree_2 run9
# Reading file: output_poc_openACC_run3_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.198262817000000 tree_2 run3
# Reading file: output_poc_openACC_run4_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.151483893000000 tree_2 run4
# Reading file: output_poc_openACC_run7_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.259827684000000 tree_2 run7
# Reading file: output_poc_openACC_run8_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.217252232000000 tree_2 run8
# Reading file: output_poc_openACC_run2_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.178072123000000 tree_2 run2
# Reading file: output_poc_openACC_run10_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.164877251000000 tree_2 run10
# Reading file: output_poc_openACC_run1_tree_2_1000000_dna_openacc_v100.txt
# tree_2
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -62357359.211786955595016 1.254657746000000 tree_2 run1
# Reading file: output_poc_openACC_run1_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.221425689000000 tree_3 run1
# Reading file: output_poc_openACC_run2_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.210865017000000 tree_3 run2
# Reading file: output_poc_openACC_run10_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.144262327000000 tree_3 run10
# Reading file: output_poc_openACC_run7_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.220442841000000 tree_3 run7
# Reading file: output_poc_openACC_run8_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.193374389000000 tree_3 run8
# Reading file: output_poc_openACC_run4_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.137105785000000 tree_3 run4
# Reading file: output_poc_openACC_run3_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.200349617000000 tree_3 run3
# Reading file: output_poc_openACC_run6_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.201916930000000 tree_3 run6
# Reading file: output_poc_openACC_run9_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.192244583000000 tree_3 run9
# Reading file: output_poc_openACC_run5_tree_3_1000000_dna_openacc_v100.txt
# tree_3
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68988749.108756780624390 1.152001906000000 tree_3 run5
# Reading file: output_poc_openACC_run3_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.196527571000000 tree_4 run3
# Reading file: output_poc_openACC_run6_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.170157101000000 tree_4 run6
# Reading file: output_poc_openACC_run9_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.250321072000000 tree_4 run9
# Reading file: output_poc_openACC_run5_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.168344253000000 tree_4 run5
# Reading file: output_poc_openACC_run1_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.194931316000000 tree_4 run1
# Reading file: output_poc_openACC_run2_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.226641873000000 tree_4 run2
# Reading file: output_poc_openACC_run10_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.209738237000000 tree_4 run10
# Reading file: output_poc_openACC_run7_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.227707636000000 tree_4 run7
# Reading file: output_poc_openACC_run8_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.164890377000000 tree_4 run8
# Reading file: output_poc_openACC_run4_tree_4_1000000_dna_openacc_v100.txt
# tree_4
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66676166.743556618690491 1.141409520000000 tree_4 run4
# Reading file: output_poc_openACC_run4_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.147870228000000 tree_5 run4
# Reading file: output_poc_openACC_run7_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.179713521000000 tree_5 run7
# Reading file: output_poc_openACC_run8_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.176595077000000 tree_5 run8
# Reading file: output_poc_openACC_run2_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.215445154000000 tree_5 run2
# Reading file: output_poc_openACC_run10_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.145711672000000 tree_5 run10
# Reading file: output_poc_openACC_run1_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.193605344000000 tree_5 run1
# Reading file: output_poc_openACC_run5_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.233642948000000 tree_5 run5
# Reading file: output_poc_openACC_run6_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.174375403000000 tree_5 run6
# Reading file: output_poc_openACC_run9_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.181886186000000 tree_5 run9
# Reading file: output_poc_openACC_run3_tree_5_1000000_dna_openacc_v100.txt
# tree_5
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -66178676.785272315144539 1.181103371000000 tree_5 run3
# Reading file: output_poc_openACC_run8_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.198735209000000 tree_6 run8
# Reading file: output_poc_openACC_run7_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.275408394000000 tree_6 run7
# Reading file: output_poc_openACC_run4_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.157577204000000 tree_6 run4
# Reading file: output_poc_openACC_run1_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.191884981000000 tree_6 run1
# Reading file: output_poc_openACC_run10_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.168104522000000 tree_6 run10
# Reading file: output_poc_openACC_run2_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.243371895000000 tree_6 run2
# Reading file: output_poc_openACC_run9_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.212361772000000 tree_6 run9
# Reading file: output_poc_openACC_run6_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.183241252000000 tree_6 run6
# Reading file: output_poc_openACC_run5_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.187938727000000 tree_6 run5
# Reading file: output_poc_openACC_run3_tree_6_1000000_dna_openacc_v100.txt
# tree_6
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -63964654.266846217215061 1.178667441000000 tree_6 run3
# Reading file: output_poc_openACC_run3_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.193537068000000 tree_7 run3
# Reading file: output_poc_openACC_run5_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.190340048000000 tree_7 run5
# Reading file: output_poc_openACC_run9_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.199054653000000 tree_7 run9
# Reading file: output_poc_openACC_run6_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.170736119000000 tree_7 run6
# Reading file: output_poc_openACC_run10_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.177317075000000 tree_7 run10
# Reading file: output_poc_openACC_run2_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.218027711000000 tree_7 run2
# Reading file: output_poc_openACC_run1_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.207501376000000 tree_7 run1
# Reading file: output_poc_openACC_run4_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.147701877000000 tree_7 run4
# Reading file: output_poc_openACC_run8_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.161063174000000 tree_7 run8
# Reading file: output_poc_openACC_run7_tree_7_1000000_dna_openacc_v100.txt
# tree_7
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68711425.513360381126404 1.194805578000000 tree_7 run7
# Reading file: output_poc_openACC_run8_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.178468325000000 tree_8 run8
# Reading file: output_poc_openACC_run7_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.216428625000000 tree_8 run7
# Reading file: output_poc_openACC_run4_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.146955541000000 tree_8 run4
# Reading file: output_poc_openACC_run1_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.186374873000000 tree_8 run1
# Reading file: output_poc_openACC_run10_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.141234297000000 tree_8 run10
# Reading file: output_poc_openACC_run2_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.218071084000000 tree_8 run2
# Reading file: output_poc_openACC_run9_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.182053584000000 tree_8 run9
# Reading file: output_poc_openACC_run6_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.159931270000000 tree_8 run6
# Reading file: output_poc_openACC_run5_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.167598189000000 tree_8 run5
# Reading file: output_poc_openACC_run3_tree_8_1000000_dna_openacc_v100.txt
# tree_8
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -65497999.130890302360058 1.203036731000000 tree_8 run3
# Reading file: output_poc_openACC_run3_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.213235537000000 tree_9 run3
# Reading file: output_poc_openACC_run5_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.190358549000000 tree_9 run5
# Reading file: output_poc_openACC_run9_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.202777073000000 tree_9 run9
# Reading file: output_poc_openACC_run6_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.179783078000000 tree_9 run6
# Reading file: output_poc_openACC_run10_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.267882540000000 tree_9 run10
# Reading file: output_poc_openACC_run2_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.203833552000000 tree_9 run2
# Reading file: output_poc_openACC_run1_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.196792819000000 tree_9 run1
# Reading file: output_poc_openACC_run4_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.152328146000000 tree_9 run4
# Reading file: output_poc_openACC_run8_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.173775163000000 tree_9 run8
# Reading file: output_poc_openACC_run7_tree_9_1000000_dna_openacc_v100.txt
# tree_9
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -71452143.169635981321335 1.208458340000000 tree_9 run7
# Reading file: output_poc_openACC_run6_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.197751230000000 tree_10 run6
# Reading file: output_poc_openACC_run1_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.195935933000000 tree_10 run1
# Reading file: output_poc_openACC_run7_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.184404328000000 tree_10 run7
# Reading file: output_poc_openACC_run9_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.199605662000000 tree_10 run9
# Reading file: output_poc_openACC_run10_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.153340976000000 tree_10 run10
# Reading file: output_poc_openACC_run8_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.178056076000000 tree_10 run8
# Reading file: output_poc_openACC_run2_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.277599331000000 tree_10 run2
# Reading file: output_poc_openACC_run5_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.180331444000000 tree_10 run5
# Reading file: output_poc_openACC_run3_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.206479943000000 tree_10 run3
# Reading file: output_poc_openACC_run4_tree_10_1000000_dna_openacc_v100.txt
# tree_10
# found a match
# OpenACC
# OpenACC_V100 100 1000000 1000000 -68040774.091122105717659 1.146963367000000 tree_10 run4
# Extracted 100 results to /Users/u7826985/Projects/Nvidia/results/2026_03_04_wholetest/results.csv
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_1_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_1_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_1_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_2_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_2_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_2_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_3_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_3_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_3_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_4_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_4_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_4_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_5_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_5_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_5_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_6_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_6_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_6_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_7_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_7_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_7_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_8_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_8_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_8_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_9_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_9_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_9_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run4_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run1_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run1_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run1_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run6_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run6_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run7_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run7_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run5_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run10_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run5_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run5_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run9_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run9_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run9_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run10_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run6_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run2_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run2_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run3_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run8_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run3_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run3_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run4_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run4_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree1CPUThread_VANILA_run8_tree_10_1000000_iqtree.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run2_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtreeOpenACC_OPENACC_run8_tree_10_1000000_iqtree.log
# OPENACC
# OPENACC
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run10_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Reading IQ-TREE file: output_test_iqtree10CPUThread_VANILA_run7_tree_10_1000000_iqtree3.log
# VANILA
# VANILA
# here
# Extracted 400 IQ-TREE results

# %%
df
# Out:
#                   backend  taxa    sites  patterns    likelihood      time  \
# 0            OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.233555
# 1            OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.206464
# 2            OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.210843
# 3            OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.232884
# 4            OpenACC_V100   100  1000000   1000000 -7.005168e+07  1.373047
# ..                    ...   ...      ...       ...           ...       ...
# 395    IQ-TREE_CPU_1_CORE   100  1000000   1000000 -6.804077e+07  1.907000
# 396  IQ-TREE_CPU_10_CORES   100  1000000   1000000 -6.804077e+07  0.355000
# 397      IQ-TREE_GPU_V100   100  1000000   1000000 -6.804077e+07  3.053000
# 398  IQ-TREE_CPU_10_CORES   100  1000000   1000000 -6.804077e+07  0.372000
# 399  IQ-TREE_CPU_10_CORES   100  1000000   1000000 -6.804077e+07  0.337000
#
#     treefile run_number
# 0     tree_1       run9
# 1     tree_1       run6
# 2     tree_1       run5
# 3     tree_1       run3
# 4     tree_1       run8
# ..       ...        ...
# 395  tree_10       run8
# 396  tree_10       run2
# 397  tree_10       run8
# 398  tree_10      run10
# 399  tree_10       run7
#
# [400 rows x 8 columns]

# %%
plot_average_time_per_backend(df, logy=False, path=f"{cwd}/average_time_per_backend_100taxa_diff_trees_1M_sites_DNA.png")

# %%
plot_min_time_per_backend(df, logy=False, path=f"{cwd}/min_time_per_backend_100taxa_diff_trees_1M_sites_DNA.png")

# %%
plot_runtime_boxplot_auto(df, path="DNA_boxonlyplot.png")
# Out:
# Using columns -> {'tree': 'treefile', 'backend': 'backend', 'time': 'time'}
# Rows plotted: 400

# %%
plot_bar_with_box(df, path="DNA_boxplot.png")
